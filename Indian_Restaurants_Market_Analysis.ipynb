# %% [markdown]
# # **Designing a Marketing Campaign for Zomato Using Exploratory Data Analysis**
# ## **Indian Restaurants Market Analysis**
#
# ##### Saba Gul

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from wordcloud import WordCloud, STOPWORDS

# %% [markdown]
# ## **Data Cleaning and Preparation:**

# %%
# Load the dataset
df = pd.read_csv("zomato_restaurants_in_India.csv", encoding='latin1')

# %%
stopwords = set(STOPWORDS)

wordcloud = (WordCloud(width=500, height=300, relative_scaling=0.5, stopwords=stopwords).generate_from_frequencies(df['name'].value_counts().head(35)))
fig = plt.figure(1,figsize=(15, 15))
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
df.shape
# Out:
# (75106, 26)

# %%
# Display the first few rows of the dataset to understand its structure
df.head(5)
# Out:
#     res_id                            name      establishment  \
# 0  3400299                     Bikanervala    ['Quick Bites']
# 1  3400005  Mama Chicken Mama Franky House    ['Quick Bites']
# 2  3401013                   Bhagat Halwai    ['Quick Bites']
# 3  3400290                   Bhagat Halwai    ['Quick Bites']
# 4  3401744     The Salt Cafe Kitchen & Bar  ['Casual Dining']
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra     34.0
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra     34.0
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra     34.0
# 3  Near Anjana Cinema, Nehru Nagar, Civil Lines, ...  Agra     34.0
# 4        1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra     34.0
#
#       locality   latitude  longitude  ... price_range  currency  \
# 0     Khandari  27.211450  78.002381  ...         2.0       Rs.
# 1   Agra Cantt  27.160569  78.011583  ...         2.0       Rs.
# 2     Shahganj  27.182938  77.979684  ...         1.0       Rs.
# 3  Civil Lines  27.205668  78.004799  ...         1.0       Rs.
# 4      Tajganj  27.157709  78.052421  ...         3.0       Rs.
#
#                                           highlights aggregate_rating  \
# 0  ['Lunch', 'Takeaway Available', 'Credit Card',...              4.4
# 1  ['Delivery', 'No Alcohol Available', 'Dinner',...              4.4
# 2  ['No Alcohol Available', 'Dinner', 'Takeaway A...              4.2
# 3  ['Takeaway Available', 'Credit Card', 'Lunch',...              4.3
# 4  ['Lunch', 'Serves Alcohol', 'Cash', 'Credit Ca...              4.9
#
#   rating_text   votes  photo_count opentable_support delivery  takeaway
# 0   Very Good   814.0        154.0               0.0     -1.0      -1.0
# 1   Very Good  1203.0        161.0               0.0     -1.0      -1.0
# 2   Very Good   801.0        107.0               0.0      1.0      -1.0
# 3   Very Good   693.0        157.0               0.0      1.0      -1.0
# 4   Excellent   470.0        291.0               0.0      1.0      -1.0
#
# [5 rows x 26 columns]

# %%
# Display the last few rows of the dataset to understand its structure
df.tail(5)
# Out:
#          res_id                             name        establishment  \
# 75101  18739658               Param Food Complex    ['Casual Dining']
# 75102  18739193                        Ice Kraft  ['Dessert Parlour']
# 75103  19015642  Twisted Toppings Pizza And Food      ['Quick Bites']
# 75104  18788845                  SB Street Foods      ['Quick Bites']
# 75105         1                              NaN                  NaN
#
#                                                      url  \
# 75101  https://www.zomato.com/gwalior/param-food-comp...
# 75102  https://www.zomato.com/gwalior/ice-kraft-city-...
# 75103  https://www.zomato.com/gwalior/twisted-topping...
# 75104  https://www.zomato.com/gwalior/sb-street-foods...
# 75105                                                NaN
#
#                                                  address     city  city_id  \
# 75101                      Moti Mahal Road Padav Gwalior  Gwalior  11337.0
# 75102                     Green Garden Road City Center   Gwalior  11337.0
# 75103                  GH 163, Deen Dayal Nagar, Gwalior  Gwalior  11337.0
# 75104  Opposite Ashiyana Complex, Near High Court, La...  Gwalior  11337.0
# 75105                                                NaN      NaN      NaN
#
#                locality   latitude  longitude  ... price_range  currency  \
# 75101           Lashkar  26.210254  78.175223  ...         3.0       Rs.
# 75102       City Center  26.208826  78.189585  ...         1.0       Rs.
# 75103  Deen Dayal Nagar  26.266111  78.208337  ...         1.0       Rs.
# 75104           Lashkar  26.207360  78.166048  ...         1.0       Rs.
# 75105               NaN        NaN        NaN  ...         NaN       NaN
#
#                                               highlights aggregate_rating  \
# 75101  ['Cash', 'Dinner', 'Takeaway Available', 'Lunc...              4.0
# 75102  ['Cash', 'Credit Card', 'Takeaway Available', ...              4.1
# 75103  ['Dinner', 'Takeaway Available', 'Lunch', 'Cas...              4.1
# 75104  ['Dinner', 'Cash', 'Lunch', 'Takeaway Availabl...              4.8
# 75105                                                NaN              NaN
#
#       rating_text  votes  photo_count opentable_support delivery  takeaway
# 75101   Very Good  240.0         10.0               0.0     -1.0      -1.0
# 75102   Very Good  128.0         87.0               0.0      1.0      -1.0
# 75103   Very Good  110.0          2.0               0.0     -1.0      -1.0
# 75104   Excellent  274.0          4.0               0.0     -1.0      -1.0
# 75105         NaN    NaN          NaN               NaN      NaN       NaN
#
# [5 rows x 26 columns]

# %%
df.columns
# Out:
# Index(['res_id', 'name', 'establishment', 'url', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'zipcode', 'country_id',
#        'locality_verbose', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'opentable_support', 'delivery',
#        'takeaway'],
#       dtype='object')

# %%
# Check data types of each column
print(df.dtypes)
# Out:
# res_id                    int64
# name                     object
# establishment            object
# url                      object
# address                  object
# city                     object
# city_id                   int64
# locality                 object
# latitude                float64
# longitude               float64
# zipcode                  object
# country_id                int64
# locality_verbose         object
# cuisines                 object
# timings                  object
# average_cost_for_two      int64
# price_range               int64
# currency                 object
# highlights               object
# aggregate_rating        float64
# rating_text              object
# votes                     int64
# photo_count               int64
# opentable_support       float64
# delivery                  int64
# takeaway                  int64
# dtype: object

# %%
# Correct data types
df['city_id'] = df['city_id'].astype('Int64')
df['country_id'] = df['country_id'].astype('Int64')
df['zipcode'] = df['zipcode'].astype(str)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211944 entries, 0 to 211943
# Data columns (total 26 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   res_id                211944 non-null  int64
#  1   name                  211944 non-null  object
#  2   establishment         211944 non-null  object
#  3   url                   211944 non-null  object
#  4   address               211810 non-null  object
#  5   city                  211944 non-null  object
#  6   city_id               211944 non-null  Int64
#  7   locality              211944 non-null  object
#  8   latitude              211944 non-null  float64
#  9   longitude             211944 non-null  float64
#  10  zipcode               211944 non-null  object
#  11  country_id            211944 non-null  Int64
#  12  locality_verbose      211944 non-null  object
#  13  cuisines              210553 non-null  object
#  14  timings               208070 non-null  object
#  15  average_cost_for_two  211944 non-null  int64
#  16  price_range           211944 non-null  int64
#  17  currency              211944 non-null  object
#  18  highlights            211944 non-null  object
#  19  aggregate_rating      211944 non-null  float64
#  20  rating_text           211944 non-null  object
#  21  votes                 211944 non-null  int64
#  22  photo_count           211944 non-null  int64
#  23  opentable_support     211896 non-null  float64
#  24  delivery              211944 non-null  int64
#  25  takeaway              211944 non-null  int64
# dtypes: Int64(2), float64(4), int64(7), object(13)
# memory usage: 42.4+ MB

# %% [markdown]
# ### Removing duplicates

# %%
df.duplicated().sum()
# Out:
# 151527

# %% [markdown]
# Its important to remove duplicate rows to avoid biasness in our analysis. Since res_id is unique identifier of our restaurants, we can use it to remove duplicates.

# %%
df.drop_duplicates(["res_id"],keep='first',inplace=True)
df.shape
# Out:
# (55568, 26)

# %%
df.columns.str.strip()
#The str.strip() function is used to remove leading and trailing characters.
#Strip whitespaces (including newlines)
# Out:
# Index(['res_id', 'name', 'establishment', 'url', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'zipcode', 'country_id',
#        'locality_verbose', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'opentable_support', 'delivery',
#        'takeaway'],
#       dtype='object')

# %% [markdown]
# ### **Check for missing values:**

# %%
df.isnull().sum()
# Out:
# res_id                     0
# name                       0
# establishment              0
# url                        0
# address                   18
# city                       0
# city_id                    0
# locality                   0
# latitude                   0
# longitude                  0
# zipcode                    0
# country_id                 0
# locality_verbose           0
# cuisines                 470
# timings                 1003
# average_cost_for_two       0
# price_range                0
# currency                   0
# highlights                 0
# aggregate_rating           0
# rating_text                0
# votes                      0
# photo_count                0
# opentable_support         12
# delivery                   0
# takeaway                   0
# dtype: int64

# %% [markdown]
# We have 5 variables with some kind of missing values. Since zipcode has more than 80% missing data, its better to not consider it at all. The other 4 features can be delt with some kind of imputation, but before going through the trouble, its better to look and decide whether they would be beneficial for our analysis or we can simply omit them.

# %%
# Handle missing values in 'cuisines' column
df['cuisines'].fillna('Unknown', inplace=True)

# %%
# Handle missing values in 'timings' column
# For the 'timings' column, we can replace missing values with a default value, such as 'Not available'
df['timings'].fillna('Not available', inplace=True)

# %% [markdown]
# ### **Omitting Irrelevant features**
# Here we will look at each feature and decide to consider them for our analysis or not:
#
# - *res_id* - Unique ID for each restaurant
# - *name* - Name is useful since we will use it to find top restaurants
# - *establishment* - Let's see what type of values we have in establishment

# %% [markdown]
# Next, we'll look for mislabeled categories or inconsistent values in data columns:

# %%
# Check unique values in 'establishment' column
print(df['establishment'].unique())
# Out:
# ["['Quick Bites']" "['Casual Dining']" "['Bakery']" "['CafÃ©']"
#  "['Dhaba']" "['Bhojanalya']" "['Bar']" "['Sweet Shop']" "['Fine Dining']"
#  "['Food Truck']" "['Dessert Parlour']" "['Lounge']" "['Pub']"
#  "['Beverage Shop']" "['Kiosk']" "['Paan Shop']" "['Confectionery']" '[]'
#  "['Shack']" "['Club']" "['Food Court']" "['Mess']" "['Butcher Shop']"
#  "['Microbrewery']" "['Cocktail Bar']" "['Pop up']" "['Irani Cafe']"]

# %%
print(df["establishment"].unique()[0])
print(type(df["establishment"].unique()[0]))
# Out:
# ['Quick Bites']
# <class 'str'>

# %% [markdown]
# The 'Establishment' feature exhibits noise with extraneous square brackets and quotes. Utilizing the apply() function, we can efficiently cleanse these artifacts. Additionally, we'll address the presence of an empty string value by renaming it to "NA" to mitigate potential confusion. This data refinement process ensures a streamlined and accurate foundation for subsequent analysis, enhancing the efficacy of our exploratory endeavors.

# %%
df["establishment"] = df["establishment"].astype(str)
# Removing [' '] from each value
print(df["establishment"].unique()[0])
df["establishment"] = df["establishment"].apply(lambda x:x[2:-2])
print(df["establishment"].unique()[0])

# Changing ''  to 'NA'
print(df["establishment"].unique())
df["establishment"] = df["establishment"].apply(lambda x : np.where(x=="", "NA", x))
print(df["establishment"].unique())
# Out:
# ['Quick Bites']
# Quick Bites
# ['Quick Bites' 'Casual Dining' 'Bakery' 'CafÃ©' 'Dhaba' 'Bhojanalya' 'Bar'
#  'Sweet Shop' 'Fine Dining' 'Food Truck' 'Dessert Parlour' 'Lounge' 'Pub'
#  'Beverage Shop' 'Kiosk' 'Paan Shop' 'Confectionery' '' 'Shack' 'Club'
#  'Food Court' 'Mess' 'Butcher Shop' 'Microbrewery' 'Cocktail Bar' 'Pop up'
#  'Irani Cafe']
# ['Quick Bites' 'Casual Dining' 'Bakery' 'CafÃ©' 'Dhaba' 'Bhojanalya' 'Bar'
#  'Sweet Shop' 'Fine Dining' 'Food Truck' 'Dessert Parlour' 'Lounge' 'Pub'
#  'Beverage Shop' 'Kiosk' 'Paan Shop' 'Confectionery' 'NA' 'Shack' 'Club'
#  'Food Court' 'Mess' 'Butcher Shop' 'Microbrewery' 'Cocktail Bar' 'Pop up'
#  'Irani Cafe']

# %%
# Check unique values in 'city' column
df['city'].unique()
# Out:
# array(['Agra', 'Ahmedabad', 'Gandhinagar', 'Ajmer', 'Alappuzha',
#        'Allahabad', 'Amravati', 'Amritsar', 'Aurangabad', 'Bangalore',
#        'Bhopal', 'Bhubaneshwar', 'Chandigarh', 'Mohali', 'Panchkula',
#        'Zirakpur', 'Nayagaon', 'Chennai', 'Coimbatore', 'Cuttack',
#        'Darjeeling', 'Dehradun', 'New Delhi', 'Gurgaon', 'Noida',
#        'Faridabad', 'Ghaziabad', 'Greater Noida', 'Dharamshala',
#        'Gangtok', 'Goa', 'Gorakhpur', 'Guntur', 'Guwahati', 'Gwalior',
#        'Haridwar', 'Hyderabad', 'Secunderabad', 'Indore', 'Jabalpur',
#        'Jaipur', 'Jalandhar', 'Jammu', 'Jamnagar', 'Jamshedpur', 'Jhansi',
#        'Jodhpur', 'Junagadh', 'Kanpur', 'Kharagpur', 'Kochi', 'Kolhapur',
#        'Kolkata', 'Howrah', 'Kota', 'Lucknow', 'Ludhiana', 'Madurai',
#        'Manali', 'Mangalore', 'Manipal', 'Udupi', 'Meerut', 'Mumbai',
#        'Thane', 'Navi Mumbai', 'Mussoorie', 'Mysore', 'Nagpur',
#        'Nainital', 'Nasik', 'Nashik', 'Neemrana', 'Ooty', 'Palakkad',
#        'Patiala', 'Patna', 'Puducherry', 'Pune', 'Pushkar', 'Raipur',
#        'Rajkot', 'Ranchi', 'Rishikesh', 'Salem', 'Shimla', 'Siliguri',
#        'Srinagar', 'Surat', 'Thrissur', 'Tirupati', 'Trichy',
#        'Trivandrum', 'Udaipur', 'Varanasi', 'Vellore', 'Vijayawada',
#        'Vizag', 'Vadodara'], dtype=object)

# %%
print(df["timings"].nunique())
print(df["timings"].unique())
# Out:
# 7741
# ['8:30am â\x80\x93 10:30pm (Mon-Sun)'
#  '12:30PM to 12Midnight (Mon, Wed, Thu, Fri, Sat, Sun), 1PM to 12Midnight (Tue)'
#  '9:30 AM to 11 PM' ...
#  '8am â\x80\x93 2:30pm, 5pm â\x80\x93 10pm (Mon-Sun)'
#  '8am â\x80\x93 3pm, 6:30pm â\x80\x93 11pm (Mon-Sun)'
#  '4pm â\x80\x93 11pm (Mon, Tue, Wed, Fri, Sat, Sun), 4pm â\x80\x93 11:30pm (Thu)']

# %% [markdown]
# This column has missing data, however it has 7741 unique classes. Also, it is not structured even if we try to reduce the number classes like we did in cuisines. Its better to omit it altogether.

# %%
df["average_cost_for_two"].nunique()
df["average_cost_for_two"].unique()
# Out:
# array([  700,   600,   300,  1000,   400,   500,  1200,  1600,   250,
#          200,   150,  1500,   800,   450,   850,   350,   900,  6000,
#          650,   550,  2500,  6500,  5500,  4300,  3600,  3500,  3200,
#         3000,  2800,  2000,  1800,  1400,  1300,  1250,  1150,  1100,
#         1050,    50,    60,   100,   750,     0,   220,   260,   950,
#         1900,  2400,  2300,  2200,  1700,  1230,    70,   140,   120,
#          470,    20,    40,   110,    80,    90,   440,  2100, 14000,
#         5000,  4500,  4100,  4000,  3700,  3400,  2700,  2600,  1650,
#         1350,   180,  1260,     2,   197,   312,   170,   240,   330,
#         3100,  4200,  1850,  3300,  4800,  3800,  3250,  2900,  1750,
#          282,    35,   149,  1550,  5100,  6600,  1450,   160,  2250,
#         8000,  7000,  3900,  3650,  1020,   320,   360,   280,   130,
#        15000,  2501,    30,  1950,  1875,  1190,   309, 12000,   380,
#          299,    45,   190,  4600,   880,    75,   620,   999, 10000,
#          505, 30000,  4050,   175,   404,   445,   640,    15,   420,
#          115,   444,   592,  1499,   208,   940,   125,  7500,   520,
#          294])

# %% [markdown]
# This is an interesting feature for our analysis, although the value "0" of average cost for 2 is strange and should be treated as an outlier

# %%
df["price_range"].unique()
# Out:
# array([2, 1, 3, 4])

# %% [markdown]
# Average prices automatically characterized into bins ranging from 1-4 with 4 being the most expensive restaurant

# %%
df["currency"].unique()
# Out:
# array(['Rs.'], dtype=object)

# %% [markdown]
#  Only one category of currency is in our data therefore, it is not useful and can be omitted from our analysis

# %%
df["highlights"].nunique()
df["highlights"].unique()
# Out:
# array(["['Lunch', 'Takeaway Available', 'Credit Card', 'Dinner', 'Cash', 'Air Conditioned', 'Indoor Seating', 'Pure Veg']",
#        "['Delivery', 'No Alcohol Available', 'Dinner', 'Takeaway Available', 'Lunch', 'Cash', 'Indoor Seating']",
#        "['No Alcohol Available', 'Dinner', 'Takeaway Available', 'Breakfast', 'Lunch', 'Cash', 'Delivery', 'Outdoor Seating', 'Air Conditioned', 'Self Service', 'Indoor Seating', 'Digital Payments Accepted', 'Pure Veg', 'Desserts and Bakes']",
#        ...,
#        "['Dinner', 'Delivery', 'Cash', 'Takeaway Available', 'Free Parking', 'Digital Payments Accepted', 'Pure Veg', 'Indoor Seating']",
#        "['Dinner', 'Cash', 'Takeaway Available', 'Lunch', 'Delivery', 'Free Parking', 'Indoor Seating', 'Air Conditioned', 'Outdoor Seating', 'Digital Payments Accepted', 'Catering Available', 'Pure Veg']",
#        "['Dinner', 'Cash', 'Takeaway Available', 'Debit Card', 'Delivery', 'Credit Card', 'Free Parking', 'Outdoor Seating']"],
#       dtype=object)

# %%
hl = []
df["highlights"].apply(lambda x : hl.extend(x[2:-2].split("', '")))
hl = pd.Series(hl)
print("Total number of unique highlights = ", hl.nunique())
# Out:
# Total number of unique highlights =  104

# %% [markdown]
# "highlights" column represents the different features that the restaurant offers and wants to highlight to their customers. Each restaurant has a list of highlights which makes the composition different for each one. We can, filter this and find total unique highlights from all restaurants.

# %%
print(df["opentable_support"].unique())
df["opentable_support"].nunique()
# Out:
# [ 0. nan]
# 1

# %% [markdown]
# "opentable_support" is ot a useful feature since it has a single category

# %%
print(df["delivery"].unique())
df["delivery"].nunique()
# Out:
# [-1  1  0]
# 3

# %% [markdown]
# "delivery" has 3 classes but there is no explanation for those labels. We can consider -1 and 0 to be one class or ignore this feature for now

# %%
print(df["locality"].nunique())
df["locality"].unique()
# Out:
# 3731
# array(['Khandari', 'Agra Cantt', 'Shahganj', ..., 'Navapura',
#        'L&T Knowledge City', 'Danteshwar'], dtype=object)

# %% [markdown]
# Although "locality" can be an interesting feature, but since the feature has so many unique classes, we will avoid it for initial analysis

# %%
print(df["country_id"].nunique())
df["country_id"].unique()
# Out:
# 1
# <IntegerArray>
# [1]
# Length: 1, dtype: Int64

# %% [markdown]
#  Since this dataset is for Indian restaurants, there should be just one unique id here as seen in the output above.

# %%
df["locality_verbose"].nunique()
df["locality_verbose"].unique()
# Out:
# array(['Khandari, Agra', 'Agra Cantt, Agra', 'Shahganj, Agra', ...,
#        'Navapura, Vadodara', 'L&T Knowledge City, Vadodara',
#        'Danteshwar, Vadodara'], dtype=object)

# %% [markdown]
# Although "locality_verbose" can be an interesting feature, but since the feature has so many unique categories, we will avoid it for initial analysis

# %%
print(df["rating_text"].nunique())
df["rating_text"].unique()
# Out:
# 33
# array(['Very Good', 'Excellent', 'Good', 'Average', 'Not rated', 'Poor',
#        'Bardzo dobrze', 'Muito Bom', 'Ä°yi', 'Ã\x87ok iyi', 'Baik',
#        'Sangat Baik', 'SkvÄ\x9blÃ©', 'Muy Bueno', 'PrÅ¯mÄ\x9br',
#        'Ortalama', 'SkvÄ\x9blÃ¡ volba', 'Muito bom', 'Velmi dobrÃ©',
#        'Excelente', 'Bom', 'Scarso', 'Promedio', 'VynikajÃºce', 'Bueno',
#        'DobrÃ©', 'Terbaik', 'Harika', 'VeÄ¾mi dobrÃ©', 'Eccellente',
#        'Buono', 'MÃ©dia', 'Dobrze'], dtype=object)

# %%
print(df["aggregate_rating"].nunique())
df["aggregate_rating"].unique()
# Out:
# 33
# array([4.4, 4.2, 4.3, 4.9, 4. , 3.8, 3.4, 4.1, 3.5, 4.6, 3.9, 3.6, 4.5,
#        4.7, 3.7, 4.8, 3.2, 0. , 3.3, 2.8, 3.1, 2.6, 3. , 2.7, 2.9, 2.2,
#        2.3, 2.4, 2.5, 2.1, 1.8, 2. , 1.9])

# %%
print(df["votes"].nunique())
df["votes"].unique()
# Out:
# 2644
# array([ 814, 1203,  801, ..., 2001, 1191, 1583])

# %%
print(df["photo_count"].nunique())
df["photo_count"].unique()
# Out:
# 2457
# array([154, 161, 107, ..., 987, 678, 828])

# %% [markdown]
# - aggregate_rating - Rating given to the restaurant
# - rating_text - Characterisation of numeric rating into bins by using labels. We will be using direct ratings in our analysis, so we can ignore this. Moreover, rating text is in different languages which would obfuscate our analysis.
# - votes - Number of votes contributing to the rating
# - photo_count - Photo uploads in reviews

# %%
df[["aggregate_rating","votes","photo_count"]].describe().loc[["mean","min","max"]]
# Out:
#       aggregate_rating         votes  photo_count
# mean          2.958593    223.330352    160.97477
# min           0.000000    -18.000000      0.00000
# max           4.900000  42539.000000  17702.00000

# %%
# Check unique values in 'cuisines' column
print(df['cuisines'].unique())
# Out:
# ['North Indian, South Indian, Mithai, Street Food, Desserts'
#  'North Indian, Mughlai, Rolls, Chinese, Fast Food, Street Food'
#  'Fast Food, Mithai' ...
#  'Street Food, Biryani, Chinese, Fast Food, North Indian, Mughlai'
#  'North Indian, Chinese, Mexican, Italian, Thai, Continental'
#  'North Indian, Lucknowi, Chinese']

# %%
df["cuisines"] = df["cuisines"].fillna("No cuisine")

# %%
cuisines = []
df["cuisines"].apply(lambda x : cuisines.extend(x.split(", ")))
cuisines = pd.Series(cuisines)
print("Total number of unique cuisines = ", cuisines.nunique())
# Out:
# Total number of unique cuisines =  134

# %% [markdown]
# For feature engineering, we can extract useful information from existing data. For example, we can extract the number of cuisines offered by each restaurant:

# %%
# Create a new column to represent the total number of cuisines offered
df['total_cuisines'] = df['cuisines'].str.split(',').apply(len)

# %%
# Display 'name of restaurant' and 'total_cuisines' columns
df_subset = df[['name', 'total_cuisines']]
print(df_subset.head())
# Out:
#                              name  total_cuisines
# 0                     Bikanervala               5
# 1  Mama Chicken Mama Franky House               6
# 2                   Bhagat Halwai               2
# 3                   Bhagat Halwai               4
# 4     The Salt Cafe Kitchen & Bar               3

# %%
# Extract useful information from 'timings' column
# df['opening_time'] = df['timings'].str.extract(r'^(\d{1,2}:\d{2}[ap]m)').fillna('')
# df['closing_time'] = df['timings'].str.extract(r'(\d{1,2}:\d{2}[ap]m)$').fillna('')

# %%
print(df.head())
# Out:
#     res_id                            name  establishment  \
# 0  3400299                     Bikanervala    Quick Bites
# 1  3400005  Mama Chicken Mama Franky House    Quick Bites
# 2  3401013                   Bhagat Halwai    Quick Bites
# 3  3400290                   Bhagat Halwai    Quick Bites
# 4  3401744     The Salt Cafe Kitchen & Bar  Casual Dining
#
#                                                  url  \
# 0  https://www.zomato.com/agra/bikanervala-khanda...
# 1  https://www.zomato.com/agra/mama-chicken-mama-...
# 2  https://www.zomato.com/agra/bhagat-halwai-2-sh...
# 3  https://www.zomato.com/agra/bhagat-halwai-civi...
# 4  https://www.zomato.com/agra/the-salt-cafe-kitc...
#
#                                              address  city  city_id  \
# 0  Kalyani Point, Near Tulsi Cinema, Bypass Road,...  Agra       34
# 1        Main Market, Sadar Bazaar, Agra Cantt, Agra  Agra       34
# 2  62/1, Near Easy Day, West Shivaji Nagar, Goalp...  Agra       34
# 3  Near Anjana Cinema, Nehru Nagar, Civil Lines, ...  Agra       34
# 4        1C,3rd Floor, Fatehabad Road, Tajganj, Agra  Agra       34
#
#       locality   latitude  longitude  ... aggregate_rating  rating_text votes  \
# 0     Khandari  27.211450  78.002381  ...              4.4    Very Good   814
# 1   Agra Cantt  27.160569  78.011583  ...              4.4    Very Good  1203
# 2     Shahganj  27.182938  77.979684  ...              4.2    Very Good   801
# 3  Civil Lines  27.205668  78.004799  ...              4.3    Very Good   693
# 4      Tajganj  27.157709  78.052421  ...              4.9    Excellent   470
#
#   photo_count opentable_support  delivery  takeaway total_cuisines  \
# 0         154               0.0        -1        -1              5
# 1         161               0.0        -1        -1              6
# 2         107               0.0         1        -1              2
# 3         157               0.0         1        -1              4
# 4         291               0.0         1        -1              3
#
#   opening_time  closing_time
# 0       8:30am
# 1
# 2
# 3
# 4
#
# [5 rows x 29 columns]

# %% [markdown]
# ## **Exploratory Data Analysis:**

# %% [markdown]
# ### **Descriptive Statistics:**

# %%
# Descriptive Statistics
print("Descriptive Statistics:")
df.describe()
# Out:
# Descriptive Statistics:
#              res_id     city_id      latitude     longitude  country_id  \
# count  2.057400e+04     20573.0  20573.000000  20573.000000     20573.0
# mean   1.148475e+07  1662.46459     21.731415     77.273745         1.0
# std    8.587143e+06   3988.5918      7.330629      9.662204         0.0
# min    1.000000e+00         1.0      0.000000      0.000000         1.0
# 25%    2.200676e+06         7.0     13.069390     76.734414         1.0
# 50%    1.843550e+07        13.0     23.179671     77.430127         1.0
# 75%    1.878581e+07        30.0     28.479964     78.200819         1.0
# max    1.915935e+07     11339.0     32.248043     91.832769         1.0
#
#        average_cost_for_two   price_range  aggregate_rating         votes  \
# count          20573.000000  20573.000000      20573.000000  20573.000000
# mean             588.749186      1.811938          3.076654    268.835270
# std              633.043342      0.933096          1.423814    682.547724
# min                0.000000      1.000000          0.000000    -18.000000
# 25%              200.000000      1.000000          2.900000      8.000000
# 50%              400.000000      2.000000          3.600000     51.000000
# 75%              700.000000      2.000000          4.000000    235.000000
# max            14000.000000      4.000000          4.900000  18967.000000
#
#         photo_count  opentable_support      delivery  takeaway  total_cuisines
# count  20573.000000            20571.0  20573.000000   20573.0    20574.000000
# mean     200.759150                0.0     -0.309581      -1.0        2.326966
# std      650.721432                0.0      0.948183       0.0        1.348905
# min        0.000000                0.0     -1.000000      -1.0        1.000000
# 25%        3.000000                0.0     -1.000000      -1.0        1.000000
# 50%       18.000000                0.0     -1.000000      -1.0        2.000000
# 75%      114.000000                0.0      1.000000      -1.0        3.000000
# max    17702.000000                0.0      1.000000      -1.0        8.000000

# %%
df.describe(include=['bool','object'])
# Out:
#                   name establishment  \
# count            20573         20574
# unique           15550            25
# top     Domino's Pizza   Quick Bites
# freq               131          4689
#
#                                                       url  \
# count                                               20573
# unique                                              20573
# top     https://www.zomato.com/agra/bikanervala-khanda...
# freq                                                    1
#
#                                                   address       city  \
# count                                               20572      20573
# unique                                              18746         35
# top     SBR Social, Beside Sattva Vikas School, Sindhu...  Bangalore
# freq                                                   21       2247
#
#            locality zipcode  locality_verbose      cuisines         timings  \
# count         20573   20574             20573         20574           20574
# unique         1618     510              1704          4462            3766
# top     Civil Lines     nan  Lashkar, Gwalior  North Indian  11 AM to 11 PM
# freq            308   15988               224          1552            2423
#
#        currency                                         highlights  \
# count     20573                                              20573
# unique        1                                              13640
# top         Rs.  ['Dinner', 'Takeaway Available', 'Lunch', 'Cas...
# freq      20573                                                275
#
#        rating_text opening_time closing_time
# count        20573        20574        20574
# unique          23           45            1
# top           Good
# freq          6050        20011        20574

# %%
# Dispersion
dispersion = df.describe(include='all')
dispersion
# Out:
#               res_id            name establishment  \
# count   2.057400e+04           20573         20574
# unique           NaN           15550            25
# top              NaN  Domino's Pizza   Quick Bites
# freq             NaN             131          4689
# mean    1.148475e+07             NaN           NaN
# std     8.587143e+06             NaN           NaN
# min     1.000000e+00             NaN           NaN
# 25%     2.200676e+06             NaN           NaN
# 50%     1.843550e+07             NaN           NaN
# 75%     1.878581e+07             NaN           NaN
# max     1.915935e+07             NaN           NaN
#
#                                                       url  \
# count                                               20573
# unique                                              20573
# top     https://www.zomato.com/agra/bikanervala-khanda...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                                   address       city  \
# count                                               20572      20573
# unique                                              18746         35
# top     SBR Social, Beside Sattva Vikas School, Sindhu...  Bangalore
# freq                                                   21       2247
# mean                                                  NaN        NaN
# std                                                   NaN        NaN
# min                                                   NaN        NaN
# 25%                                                   NaN        NaN
# 50%                                                   NaN        NaN
# 75%                                                   NaN        NaN
# max                                                   NaN        NaN
#
#            city_id     locality      latitude     longitude  ...  \
# count      20573.0        20573  20573.000000  20573.000000  ...
# unique        <NA>         1618           NaN           NaN  ...
# top           <NA>  Civil Lines           NaN           NaN  ...
# freq          <NA>          308           NaN           NaN  ...
# mean    1662.46459          NaN     21.731415     77.273745  ...
# std      3988.5918          NaN      7.330629      9.662204  ...
# min            1.0          NaN      0.000000      0.000000  ...
# 25%            7.0          NaN     13.069390     76.734414  ...
# 50%           13.0          NaN     23.179671     77.430127  ...
# 75%           30.0          NaN     28.479964     78.200819  ...
# max        11339.0          NaN     32.248043     91.832769  ...
#
#        aggregate_rating  rating_text         votes   photo_count  \
# count      20573.000000        20573  20573.000000  20573.000000
# unique              NaN           23           NaN           NaN
# top                 NaN         Good           NaN           NaN
# freq                NaN         6050           NaN           NaN
# mean           3.076654          NaN    268.835270    200.759150
# std            1.423814          NaN    682.547724    650.721432
# min            0.000000          NaN    -18.000000      0.000000
# 25%            2.900000          NaN      8.000000      3.000000
# 50%            3.600000          NaN     51.000000     18.000000
# 75%            4.000000          NaN    235.000000    114.000000
# max            4.900000          NaN  18967.000000  17702.000000
#
#        opentable_support      delivery  takeaway total_cuisines opening_time  \
# count            20571.0  20573.000000   20573.0   20574.000000        20574
# unique               NaN           NaN       NaN            NaN           45
# top                  NaN           NaN       NaN            NaN
# freq                 NaN           NaN       NaN            NaN        20011
# mean                 0.0     -0.309581      -1.0       2.326966          NaN
# std                  0.0      0.948183       0.0       1.348905          NaN
# min                  0.0     -1.000000      -1.0       1.000000          NaN
# 25%                  0.0     -1.000000      -1.0       1.000000          NaN
# 50%                  0.0     -1.000000      -1.0       2.000000          NaN
# 75%                  0.0      1.000000      -1.0       3.000000          NaN
# max                  0.0      1.000000      -1.0       8.000000          NaN
#
#         closing_time
# count          20574
# unique             1
# top
# freq           20574
# mean             NaN
# std              NaN
# min              NaN
# 25%              NaN
# 50%              NaN
# 75%              NaN
# max              NaN
#
# [11 rows x 29 columns]

# %% [markdown]
# ### **Distribution Analysis for key variables:**

# %%
# Distribution Analysis
# Ratings distribution
ratings_distribution = df['aggregate_rating'].value_counts()
ratings_distribution
# Out:
# aggregate_rating
# 0.0    3289
# 4.0    1427
# 3.9    1409
# 3.8    1305
# 3.7    1243
# 4.1    1235
# 3.6    1112
# 4.2     999
# 3.5     989
# 3.4     946
# 3.3     905
# 3.2     864
# 4.3     733
# 3.1     573
# 2.9     528
# 4.4     485
# 3.0     454
# 2.8     374
# 4.5     315
# 2.7     315
# 2.6     217
# 4.6     190
# 2.5     173
# 2.4     133
# 4.7     113
# 2.3      77
# 4.8      61
# 4.9      54
# 2.2      29
# 2.1      17
# 2.0       5
# 1.9       3
# 1.8       1
# Name: count, dtype: int64

# %%
# Price range distribution
price_range_distribution = df['price_range'].value_counts()

# Total cuisines distribution
total_cuisines_distribution = df['total_cuisines'].value_counts()

# %%
import matplotlib.pyplot as plt

# Distribution of ratings
plt.hist(df['aggregate_rating'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of price range
plt.hist(df['price_range'], bins=range(1, 7), color='lightgreen')
plt.title('Distribution of Price Range')
plt.xlabel('Price Range')
plt.ylabel('Frequency')
plt.xticks(range(1, 6))
plt.show()

# %%
# Distribution of cuisine type offered by each returant
df['cuisines'].hist(color='salmon', bins=range(1, 15))
plt.title('Distribution of Cuisine Type')
plt.xlabel('Name of Cuisines')
plt.ylabel('Frequency')
plt.xticks(range(1, 15))
# Rotate x-axis labels at 90 degrees
plt.xticks(rotation=90)
plt.show()

# %%
# Distribution of total cuisines offered by each resturant
df['total_cuisines'].hist(color='purple')
plt.title('Distribution of Total Cuisines')
plt.xlabel('Number of Cuisines')
plt.ylabel('Frequency')
plt.show()

# %%
# Distribution of price range
df['price_range'].hist()
plt.title('Distribution of Price Range')
plt.xlabel('Price Range')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### **Correlation Analysis:**

# %%
# Calculate correlation for numeric data only
numeric_correlation = df.corr(numeric_only=True)
numeric_correlation

# Create heatmap
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(numeric_correlation, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# ### **Restaurant chains**
# #### Chains vs Outlets

# %%
outlets = df["name"].value_counts()
outlets
# Out:
# name
# Domino's Pizza             131
# Cafe Coffee Day            112
# Keventers                   86
# KFC                         79
# Baskin Robbins              77
#                           ...
# Murli                        1
# Malabar Bay                  1
# BYLI - Bet You Love It!      1
# Silbatti                     1
# Hotel Mascot                 1
# Name: count, Length: 15550, dtype: int64

# %%
chains = outlets[outlets >= 2]
single = outlets[outlets == 1]

# %%
chains
# Out:
# name
# Domino's Pizza               131
# Cafe Coffee Day              112
# Keventers                     86
# KFC                           79
# Baskin Robbins                77
#                             ...
# Delhi Soya Chaap Wala          2
# Karnavati Snacks               2
# Pawan's Bikaner Bhujiwala      2
# Black Deer                     2
# Alaturka                       2
# Name: count, Length: 1626, dtype: int64

# %%
single
# Out:
# name
# Sangam Food Point               1
# Bowwow                          1
# Eltham Bakery & Coffee House    1
# Empire The Meat Shop            1
# Madison & Pike                  1
#                                ..
# Murli                           1
# Malabar Bay                     1
# BYLI - Bet You Love It!         1
# Silbatti                        1
# Hotel Mascot                    1
# Name: count, Length: 13924, dtype: int64

# %%
print("Total Restaurants = ", df.shape[0])
print("Total Restaurants that are part of some chain = ", df.shape[0] - chains.shape[0])
print("Percentage of Restaurants that are part of a chain = ", np.round((df.shape[0] - chains.shape[0]) / df.shape[0],2)*100, "%")
# Out:
# Total Restaurants =  20574
# Total Restaurants that are part of some chain =  18948
# Percentage of Restaurants that are part of a chain =  92.0 %

# %%
print("Total Restaurants = ", df.shape[0])
print("Total Restaurants that have a Single Outlet = ", df.shape[0] - single.shape[0])
print("Percentage of Restaurants that have a Single Outlet = ", np.round((df.shape[0] - single.shape[0]) / df.shape[0],2)*100, "%")
# Out:
# Total Restaurants =  20574
# Total Restaurants that have a Single Outlet =  6650
# Percentage of Restaurants that have a Single Outlet =  32.0 %

# %% [markdown]
# ## Regional Analysis:
# - Compare the restaurant trends and customer preferences across different
# cities or regions in India.
# - Identify unique characteristics of the dining scene in each region.

# %%
# Group the data by city or region
grouped_data = df.groupby('city')

# Iterate over groups and analyze key variables
for city, data in grouped_data:
    print(f"City: {city}")
    # Perform analysis for each city or region
    # Example: Calculate average ratings, popular cuisines, etc.
    avg_rating = data['aggregate_rating'].mean()
    popular_cuisines = data['cuisines'].value_counts().head(3)
    # Print or visualize the findings
    print(f"Average Rating: {avg_rating}")
    print("Popular Cuisines:")
    print(popular_cuisines)
    print("-" * 30)
# Out:
# City: Agra
# Average Rating: 2.6612244897959187
# Popular Cuisines:
# cuisines
# North Indian    114
# Mithai           53
# Fast Food        39
# Name: count, dtype: int64
# ------------------------------
# City: Ahmedabad
# Average Rating: 3.20962309542903
# Popular Cuisines:
# cuisines
# Street Food     80
# North Indian    74
# Fast Food       71
# Name: count, dtype: int64
# ------------------------------
# City: Ajmer
# Average Rating: 2.5864999999999996
# Popular Cuisines:
# cuisines
# North Indian    73
# Fast Food       33
# Mithai          12
# Name: count, dtype: int64
# ------------------------------
# City: Alappuzha
# Average Rating: 0.3796078431372549
# Popular Cuisines:
# cuisines
# Bakery                  53
# Kerala                  38
# South Indian, Kerala    22
# Name: count, dtype: int64
# ------------------------------
# City: Allahabad
# Average Rating: 2.7252285191956127
# Popular Cuisines:
# cuisines
# North Indian             101
# North Indian, Chinese     32
# Desserts                  28
# Name: count, dtype: int64
# ------------------------------
# City: Amravati
# Average Rating: 1.6907894736842106
# Popular Cuisines:
# cuisines
# North Indian     42
# Fast Food        29
# Maharashtrian    16
# Name: count, dtype: int64
# ------------------------------
# City: Amritsar
# Average Rating: 2.8788888888888895
# Popular Cuisines:
# cuisines
# North Indian             113
# Mithai                    25
# North Indian, Chinese     24
# Name: count, dtype: int64
# ------------------------------
# City: Aurangabad
# Average Rating: 2.7738998482549317
# Popular Cuisines:
# cuisines
# North Indian             59
# North Indian, Chinese    42
# Fast Food                31
# Name: count, dtype: int64
# ------------------------------
# City: Bangalore
# Average Rating: 3.6981753449043167
# Popular Cuisines:
# cuisines
# South Indian           101
# Mithai, Street Food     99
# North Indian            62
# Name: count, dtype: int64
# ------------------------------
# City: Bhopal
# Average Rating: 2.83719646799117
# Popular Cuisines:
# cuisines
# North Indian             116
# Fast Food                 36
# North Indian, Chinese     36
# Name: count, dtype: int64
# ------------------------------
# City: Bhubaneshwar
# Average Rating: 3.070942408376963
# Popular Cuisines:
# cuisines
# Fast Food                36
# North Indian             32
# North Indian, Chinese    31
# Name: count, dtype: int64
# ------------------------------
# City: Chandigarh
# Average Rating: 3.4722817764165383
# Popular Cuisines:
# cuisines
# North Indian             60
# North Indian, Chinese    21
# Pizza, Fast Food         18
# Name: count, dtype: int64
# ------------------------------
# City: Chennai
# Average Rating: 3.5977011494252875
# Popular Cuisines:
# cuisines
# South Indian           97
# Ice Cream, Desserts    55
# Finger Food            54
# Name: count, dtype: int64
# ------------------------------
# City: Coimbatore
# Average Rating: 2.802663934426229
# Popular Cuisines:
# cuisines
# South Indian    78
# Bakery          53
# Beverages       36
# Name: count, dtype: int64
# ------------------------------
# City: Cuttack
# Average Rating: 2.820350877192982
# Popular Cuisines:
# cuisines
# North Indian, Chinese    31
# Fast Food                28
# North Indian             28
# Name: count, dtype: int64
# ------------------------------
# City: Darjeeling
# Average Rating: 0.9612068965517241
# Popular Cuisines:
# cuisines
# Unknown      21
# Bakery        7
# Fast Food     7
# Name: count, dtype: int64
# ------------------------------
# City: Dehradun
# Average Rating: 2.803006535947712
# Popular Cuisines:
# cuisines
# North Indian             95
# North Indian, Chinese    50
# Fast Food                42
# Name: count, dtype: int64
# ------------------------------
# City: Dharamshala
# Average Rating: 1.636326530612245
# Popular Cuisines:
# cuisines
# North Indian             30
# North Indian, Chinese    25
# Cafe                     21
# Name: count, dtype: int64
# ------------------------------
# City: Faridabad
# Average Rating: 3.2569620253164557
# Popular Cuisines:
# cuisines
# North Indian                      13
# Bakery                             4
# Desserts, Ice Cream, Beverages     4
# Name: count, dtype: int64
# ------------------------------
# City: Gandhinagar
# Average Rating: 2.853125
# Popular Cuisines:
# cuisines
# Pizza, Fast Food    6
# North Indian        5
# Gujarati            5
# Name: count, dtype: int64
# ------------------------------
# City: Gangtok
# Average Rating: 1.3893939393939392
# Popular Cuisines:
# cuisines
# Unknown      16
# Fast Food     9
# Chinese       8
# Name: count, dtype: int64
# ------------------------------
# City: Ghaziabad
# Average Rating: 3.4877777777777776
# Popular Cuisines:
# cuisines
# North Indian                    12
# Burger, Fast Food, Beverages     5
# North Indian, Chinese            4
# Name: count, dtype: int64
# ------------------------------
# City: Goa
# Average Rating: 3.0300869565217394
# Popular Cuisines:
# cuisines
# Bakery, Desserts    56
# Finger Food         37
# Cafe                30
# Name: count, dtype: int64
# ------------------------------
# City: Gorakhpur
# Average Rating: 2.336897274633124
# Popular Cuisines:
# cuisines
# North Indian    67
# Bakery          36
# Fast Food       27
# Name: count, dtype: int64
# ------------------------------
# City: Greater Noida
# Average Rating: 3.40952380952381
# Popular Cuisines:
# cuisines
# Burger, Fast Food, Beverages    2
# North Indian                    2
# Fast Food, Burger               1
# Name: count, dtype: int64
# ------------------------------
# City: Guntur
# Average Rating: 2.9703703703703703
# Popular Cuisines:
# cuisines
# South Indian                      20
# Biryani                           11
# Biryani, North Indian, Chinese     9
# Name: count, dtype: int64
# ------------------------------
# City: Gurgaon
# Average Rating: 3.828524590163934
# Popular Cuisines:
# cuisines
# North Indian        27
# Tea, Fast Food      14
# Bakery, Desserts    13
# Name: count, dtype: int64
# ------------------------------
# City: Guwahati
# Average Rating: 3.1068870523415972
# Popular Cuisines:
# cuisines
# North Indian, Chinese    49
# North Indian             27
# Finger Food              25
# Name: count, dtype: int64
# ------------------------------
# City: Gwalior
# Average Rating: 2.712434325744308
# Popular Cuisines:
# cuisines
# North Indian             115
# Fast Food                 35
# North Indian, Chinese     23
# Name: count, dtype: int64
# ------------------------------
# City: Mohali
# Average Rating: 3.1097484276729563
# Popular Cuisines:
# cuisines
# North Indian             45
# North Indian, Chinese    17
# Pizza, Fast Food         10
# Name: count, dtype: int64
# ------------------------------
# City: Nayagaon
# Average Rating: 2.246666666666667
# Popular Cuisines:
# cuisines
# North Indian            3
# Mithai, Street Food     2
# Fast Food, Beverages    2
# Name: count, dtype: int64
# ------------------------------
# City: New Delhi
# Average Rating: 3.727347417840375
# Popular Cuisines:
# cuisines
# North Indian    128
# Street Food      45
# Paan             40
# Name: count, dtype: int64
# ------------------------------
# City: Noida
# Average Rating: 3.620306513409962
# Popular Cuisines:
# cuisines
# North Indian                    9
# Burger, Fast Food, Beverages    7
# Fast Food                       6
# Name: count, dtype: int64
# ------------------------------
# City: Panchkula
# Average Rating: 3.1375
# Popular Cuisines:
# cuisines
# North Indian    13
# Fast Food        9
# Street Food      5
# Name: count, dtype: int64
# ------------------------------
# City: Zirakpur
# Average Rating: 2.8033333333333332
# Popular Cuisines:
# cuisines
# North Indian             22
# North Indian, Chinese     6
# Pizza, Fast Food          5
# Name: count, dtype: int64
# ------------------------------

# %%
# Group the data by city
city_grouped = df.groupby('city')

# Calculate aggregate statistics
city_stats = city_grouped.agg({
    'name': 'count',  # Number of restaurants
    'aggregate_rating': 'mean',  # Average rating
    'average_cost_for_two': 'mean',  # Average cost for two
    'cuisines': lambda x: x.value_counts().index[0]  # Most common cuisine
})

# Display the aggregated statistics
print(city_stats)
# Out:
#                name  aggregate_rating  average_cost_for_two  \
# city
# Agra            833          2.661224            520.600240
# Ahmedabad      1247          3.209623            492.750601
# Ajmer           400          2.586500            307.625000
# Alappuzha       255          0.379608            302.549020
# Allahabad       547          2.725229            353.546618
# Amravati        380          1.690789            213.578947
# Amritsar        630          2.878889            469.634921
# Aurangabad      659          2.773900            406.039454
# Bangalore      2247          3.698175            799.105474
# Bhopal          906          2.837196            408.972406
# Bhubaneshwar    764          3.070942            443.850785
# Chandigarh      653          3.472282            663.981623
# Chennai        1827          3.597701            731.970443
# Coimbatore      976          2.802664            427.071721
# Cuttack         285          2.820351            343.508772
# Darjeeling      116          0.961207            416.250000
# Dehradun        765          2.803007            445.645752
# Dharamshala     245          1.636327            425.591837
# Faridabad        79          3.256962            684.177215
# Gandhinagar      96          2.853125            419.270833
# Gangtok         132          1.389394            512.954545
# Ghaziabad        90          3.487778            595.555556
# Goa            1150          3.030087            793.286957
# Gorakhpur       477          2.336897            295.010482
# Greater Noida    21          3.409524            473.809524
# Guntur          270          2.970370            336.740741
# Gurgaon         610          3.828525            982.262295
# Guwahati        726          3.106887            505.523416
# Gwalior         571          2.712434            329.054291
# Mohali          318          3.109748            441.855346
# Nayagaon         15          2.246667            336.666667
# New Delhi      1704          3.727347            994.870892
# Noida           261          3.620307            734.980843
# Panchkula       168          3.137500            607.440476
# Zirakpur        150          2.803333            556.333333
#
#                                    cuisines
# city
# Agra                           North Indian
# Ahmedabad                       Street Food
# Ajmer                          North Indian
# Alappuzha                            Bakery
# Allahabad                      North Indian
# Amravati                       North Indian
# Amritsar                       North Indian
# Aurangabad                     North Indian
# Bangalore                      South Indian
# Bhopal                         North Indian
# Bhubaneshwar                      Fast Food
# Chandigarh                     North Indian
# Chennai                        South Indian
# Coimbatore                     South Indian
# Cuttack               North Indian, Chinese
# Darjeeling                          Unknown
# Dehradun                       North Indian
# Dharamshala                    North Indian
# Faridabad                      North Indian
# Gandhinagar                Pizza, Fast Food
# Gangtok                             Unknown
# Ghaziabad                      North Indian
# Goa                        Bakery, Desserts
# Gorakhpur                      North Indian
# Greater Noida  Burger, Fast Food, Beverages
# Guntur                         South Indian
# Gurgaon                        North Indian
# Guwahati              North Indian, Chinese
# Gwalior                        North Indian
# Mohali                         North Indian
# Nayagaon                       North Indian
# New Delhi                      North Indian
# Noida                          North Indian
# Panchkula                      North Indian
# Zirakpur                       North Indian

# %%
# Visualization
# Plotting the average ratings
plt.figure(figsize=(10, 6))
plt.bar(city_stats.index, city_stats['aggregate_rating'], color='skyblue')
plt.xlabel('City')
plt.ylabel('Average Rating')
plt.title('Average Ratings by City')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
# Plotting the most common cuisine
plt.figure(figsize=(10, 6))
city_stats['cuisines'].value_counts().plot(kind='bar', color='lightgreen')
plt.xlabel('Cuisine')
plt.ylabel('Frequency')
plt.title('Most Common Cuisine ')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %% [markdown]
# ## Customer Preference Analysis:
# - Analyze the types of cuisines that are popular in different regions.
# - Examine the relationship between restaurant ratings, price range, and
# popularity.

# %%
# Analyze the types of cuisines that are popular in different regions
popular_cuisines = df['cuisines'].value_counts().head(10)
print("Top 10 Popular Cuisines:")
print(popular_cuisines)
# Out:
# Top 10 Popular Cuisines:
# cuisines
# North Indian             1552
# Fast Food                 669
# North Indian, Chinese     616
# Bakery                    540
# South Indian              458
# Street Food               378
# Cafe                      354
# Mithai                    320
# Desserts                  304
# Beverages                 291
# Name: count, dtype: int64

# %%
# Examine the relationship between restaurant ratings, price range, and popularity

sns.pairplot(df[['aggregate_rating', 'price_range', 'votes']])
plt.title('Relationship between Ratings, Price Range, and Popularity')
plt.show()

# %%
# Analyze popular cuisines in different regions
popular_cuisines_by_region = df.groupby('city')['cuisines'].apply(lambda x: pd.Series(x.str.split(',').sum()).value_counts().head(5))

# %%
# Display the top 5 popular cuisines in each region
print("Top 5 Popular Cuisines in Different Regions:")
print(popular_cuisines_by_region)
# Out:
# Top 5 Popular Cuisines in Different Regions:
# city
# Agra      North Indian     277
#            Chinese         142
#            Fast Food       118
#           Mithai            99
#            Continental      83
#                           ...
# Zirakpur  North Indian      54
#            Fast Food        36
#            Chinese          34
#            Desserts         17
#            North Indian     16
# Name: cuisines, Length: 175, dtype: int64

# %%
# Examine the relationship between restaurant ratings, price range, and popularity
ratings_price_range_popularity = df[['aggregate_rating', 'price_range', 'votes']]
correlation_matrix = ratings_price_range_popularity.corr()

# %%
# Display correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#                   aggregate_rating  price_range     votes
# aggregate_rating          1.000000     0.269725  0.297260
# price_range               0.269725     1.000000  0.246619
# votes                     0.297260     0.246619  1.000000

# %%
# Create heatmap
plt.figure(figsize=(10, 8))  # Adjust the figure size as needed
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# The correlation matrix indicates the correlation coefficients between different variables:
#
# - **aggregate_rating** (Restaurant Rating): This column represents the aggregate rating of restaurants. It shows a moderate positive correlation with both the price range and the number of votes, indicating that restaurants with higher ratings tend to have higher price ranges and attract more votes.
#
# - **price_range**: This column represents the price range of restaurants. It shows a moderate positive correlation with both the aggregate rating and the number of votes. This suggests that restaurants with higher price ranges tend to have higher ratings and attract more votes.
#
# - **votes**: This column represents the number of votes received by restaurants. It shows a moderate positive correlation with both the aggregate rating and the price range. This implies that restaurants with more votes tend to have higher ratings and higher price ranges.

# %% [markdown]
# ## Competitive Analysis:
# - Identify major competitors in each region based on cuisine, pricing, and
# ratings.
# - Analyze the strengths and weaknesses of these competitors.

# %%
# Group the data by city or region to identify major competitors
competitors_by_region = df.groupby('city')

# Iterate over each group (city or region) to analyze competitors
for city, data in competitors_by_region:
    print(f"\nCompetitive Analysis for {city}:")

    # Identify major competitors based on cuisine, pricing, and ratings
    major_competitors = data[['name', 'cuisines', 'price_range', 'aggregate_rating']]

    # Sort competitors by aggregate rating in descending order
    major_competitors = major_competitors.sort_values(by='aggregate_rating', ascending=False)

    # Display top competitors
    print("Top Competitors:")
    print(major_competitors.head())

    # Analyze strengths and weaknesses
    print("\nStrengths and Weaknesses:")
    # You can perform further analysis based on your criteria, such as comparing cuisines, pricing, and ratings.
    # For example, you can calculate average ratings and pricing for each cuisine to identify strengths and weaknesses.
    avg_rating_by_cuisine = data.groupby('cuisines')['aggregate_rating'].mean()
    avg_price_by_cuisine = data.groupby('cuisines')['price_range'].mean()
    print("Average Ratings by Cuisine:")
    print(avg_rating_by_cuisine)
    print("\nAverage Price Range by Cuisine:")
    print(avg_price_by_cuisine)
# Out:
# Competitive Analysis for Agra:
# Top Competitors:
#                                 name  \
# 4        The Salt Cafe Kitchen & Bar
# 64                   Sheroes Hangout
# 36  Tea'se Me - Rooftop Tea Boutique
# 59                         D'Delicia
# 22                    Pinch Of Spice
#
#                                        cuisines  price_range  aggregate_rating
# 4            North Indian, Continental, Italian          3.0               4.9
# 64                  Cafe, North Indian, Chinese          1.0               4.8
# 36  Chinese, Italian, Continental, North Indian          3.0               4.7
# 59      North Indian, Chinese, Mexican, Italian          4.0               4.7
# 22           North Indian, Chinese, Continental          4.0               4.6
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Asian, European, North Indian, Mediterranean               4.100000
# Asian, North Indian, Chinese                               0.000000
# Asian, North Indian, Chinese, South Indian, Italian        0.000000
# Asian, South Indian, Continental, Chinese, North Indian    0.000000
# Awadhi, Chinese, Mughlai, North Indian                     3.900000
#                                                              ...
# Street Food, Mithai                                        3.600000
# Tea                                                        2.233333
# Tea, Fast Food                                             2.150000
# Tea, Street Food                                           3.900000
# Unknown                                                    3.600000
# Name: aggregate_rating, Length: 231, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Asian, European, North Indian, Mediterranean               4.0
# Asian, North Indian, Chinese                               3.0
# Asian, North Indian, Chinese, South Indian, Italian        3.0
# Asian, South Indian, Continental, Chinese, North Indian    4.0
# Awadhi, Chinese, Mughlai, North Indian                     1.0
#                                                           ...
# Street Food, Mithai                                        1.0
# Tea                                                        1.0
# Tea, Fast Food                                             1.0
# Tea, Street Food                                           1.0
# Unknown                                                    1.0
# Name: price_range, Length: 231, dtype: float64
#
# Competitive Analysis for Ahmedabad:
# Top Competitors:
#                                      name  \
# 2718                       Yanki Sizzlers
# 2754  TGâs - The Oriental Grill - Hyatt
# 2688                           Buttercupp
# 2705                       Yanki Sizzlers
# 2628                        Huber & Holly
#
#                                     cuisines  price_range  aggregate_rating
# 2718  Continental, Italian, Chinese, Mexican          3.0               4.9
# 2754                       Chinese, Japanese          4.0               4.9
# 2688                        Desserts, Bakery          1.0               4.9
# 2705           Continental, Italian, Chinese          3.0               4.9
# 2628                       Desserts, Italian          2.0               4.8
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Indian, Indonesian, Afghan       0.00
# Andhra, Konkan, Kerala, South Indian       4.70
# Arabian                                    3.40
# Arabian, Lebanese                          3.80
# Asian, American, North Indian, Gujarati    4.00
#                                            ...
# Street Food, North Indian                  3.60
# Street Food, South Indian                  2.60
# Tea, Fast Food, Beverages                  3.75
# Thai, Chinese                              2.10
# Wraps                                      3.20
# Name: aggregate_rating, Length: 310, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Indian, Indonesian, Afghan       1.0
# Andhra, Konkan, Kerala, South Indian       4.0
# Arabian                                    2.0
# Arabian, Lebanese                          2.0
# Asian, American, North Indian, Gujarati    4.0
#                                           ...
# Street Food, North Indian                  1.0
# Street Food, South Indian                  1.0
# Tea, Fast Food, Beverages                  1.5
# Thai, Chinese                              2.5
# Wraps                                      2.0
# Name: price_range, Length: 310, dtype: float64
#
# Competitive Analysis for Ajmer:
# Top Competitors:
#                          name  \
# 5936  Mango Masala Restaurant
# 5937                    Rasoi
# 5944                  Foodies
# 5951              Mango Curry
# 5992        Pandit Restaurant
#
#                                                cuisines  price_range  \
# 5936  Continental, Beverages, South Indian, Fast Foo...          2.0
# 5937  North Indian, South Indian, Continental, Itali...          3.0
# 5944                                            Chinese          1.0
# 5951  South Indian, Fast Food, Italian, North Indian...          3.0
# 5992                              Biryani, North Indian          1.0
#
#       aggregate_rating
# 5936               4.8
# 5937               4.6
# 5944               4.5
# 5951               4.5
# 5992               4.4
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Afghan                                                                       0.000000
# BBQ, Beverages, Biryani, Burger, Cafe, North Indian                          3.300000
# BBQ, Chinese, Cafe, Roast Chicken, Beverages, North Indian, Burger, Pizza    3.600000
# BBQ, Chinese, Roast Chicken, North Indian, Kebab, Afghan, Mughlai            4.000000
# Bakery                                                                       2.090909
#                                                                                ...
# Street Food, Fast Food, Sandwich, Pizza, Chinese, Momos, Coffee              3.700000
# Street Food, Tea, Beverages, North Indian, Chinese, Salad, Coffee            3.500000
# Tea, Street Food                                                             3.200000
# Thai, Mexican, Italian                                                       3.500000
# Unknown                                                                      0.000000
# Name: aggregate_rating, Length: 174, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Afghan                                                                       3.000000
# BBQ, Beverages, Biryani, Burger, Cafe, North Indian                          2.000000
# BBQ, Chinese, Cafe, Roast Chicken, Beverages, North Indian, Burger, Pizza    1.000000
# BBQ, Chinese, Roast Chicken, North Indian, Kebab, Afghan, Mughlai            2.000000
# Bakery                                                                       1.181818
#                                                                                ...
# Street Food, Fast Food, Sandwich, Pizza, Chinese, Momos, Coffee              1.000000
# Street Food, Tea, Beverages, North Indian, Chinese, Salad, Coffee            1.000000
# Tea, Street Food                                                             1.000000
# Thai, Mexican, Italian                                                       1.000000
# Unknown                                                                      1.000000
# Name: price_range, Length: 174, dtype: float64
#
# Competitive Analysis for Alappuzha:
# Top Competitors:
#                              name                        cuisines  \
# 9222  Kalhara Cafe and Restaurant            Arabian, Continental
# 9215                Arabian Shake  Beverages, Desserts, Fast Food
# 9227             Halal Food Court                          Kerala
# 9236   Rahumath Family Restaurant   South Indian, Kerala, Seafood
# 9223                 Cafe Pumpkin                       Fast Food
#
#       price_range  aggregate_rating
# 9222          2.0               4.0
# 9215          2.0               4.0
# 9227          1.0               3.9
# 9236          2.0               3.9
# 9223          1.0               3.8
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Arabian, Continental                           4.0
# Arabian, Juices                                0.0
# Arabian, North Indian, South Indian            0.0
# Arabian, South Indian                          0.0
# Asian, Continental                             0.0
#                                               ...
# South Indian, North Indian, Kerala, Chinese    0.0
# South Indian, North Indian, Seafood            0.0
# Tea, Beverages, South Indian                   0.0
# Tea, Street Food                               0.0
# Thai, Indian, Continental, Chinese, Seafood    3.3
# Name: aggregate_rating, Length: 82, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Arabian, Continental                           2.0
# Arabian, Juices                                2.0
# Arabian, North Indian, South Indian            2.0
# Arabian, South Indian                          1.0
# Asian, Continental                             4.0
#                                               ...
# South Indian, North Indian, Kerala, Chinese    2.0
# South Indian, North Indian, Seafood            2.0
# Tea, Beverages, South Indian                   1.0
# Tea, Street Food                               1.0
# Thai, Indian, Continental, Chinese, Seafood    2.0
# Name: price_range, Length: 82, dtype: float64
#
# Competitive Analysis for Allahabad:
# Top Competitors:
#                       name                            cuisines  price_range  \
# 11147               Eat On                        North Indian          1.0
# 11220  The Vintage Kitchen    North Indian, Chinese, Fast Food          3.0
# 11161      Barbeque Nation         North Indian, Mediterranean          4.0
# 11155  EDEN by Connoisseur  North Indian, Chinese, Continental          4.0
# 11180                 Malt             Cafe, Beverages, Bakery          2.0
#
#        aggregate_rating
# 11147               4.8
# 11220               4.7
# 11161               4.7
# 11155               4.6
# 11180               4.5
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Arabian, Fast Food                        3.800000
# Bakery                                    2.007692
# Bakery, Desserts                          2.783333
# Bakery, Ice Cream                         0.000000
# Bakery, Italian, Continental, Desserts    4.000000
#                                             ...
# Street Food, Fast Food                    3.100000
# Street Food, North Indian, Fast Food      2.950000
# Street Food, South Indian, Mithai         3.000000
# Tea, Fast Food, North Indian              0.000000
# Unknown                                   0.000000
# Name: aggregate_rating, Length: 166, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Arabian, Fast Food                        1.000000
# Bakery                                    1.692308
# Bakery, Desserts                          1.333333
# Bakery, Ice Cream                         1.000000
# Bakery, Italian, Continental, Desserts    2.000000
#                                             ...
# Street Food, Fast Food                    1.000000
# Street Food, North Indian, Fast Food      1.500000
# Street Food, South Indian, Mithai         1.000000
# Tea, Fast Food, North Indian              1.000000
# Unknown                                   1.000000
# Name: price_range, Length: 166, dtype: float64
#
# Competitive Analysis for Amravati:
# Top Competitors:
#                                  name  \
# 13269                  Hotel Abdullah
# 13264            New Eagle Restaurant
# 13263  New Punjabi Dhaba & Restaurant
# 13265           Al Basheer Restaurant
# 13284                   Kanhaiya Kunj
#
#                                       cuisines  price_range  aggregate_rating
# 13269  Biryani, North Indian, Seafood, Chinese          1.0               4.9
# 13264                             North Indian          1.0               4.6
# 13263              North Indian, Maharashtrian          1.0               4.5
# 13265                             North Indian          1.0               4.4
# 13284                                   Indian          1.0               4.4
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Bakery                                                                         1.877778
# Bakery, Beverages                                                              0.000000
# Bakery, Burger, Cafe, Coffee                                                   0.000000
# Bakery, Burger, Cafe, Coffee, Indian, Pizza, Sandwich                          3.000000
# Bakery, Cafe, Chinese, Coffee, Fast Food, Healthy Food, Indian, Pizza          3.700000
#                                                                                  ...
# South Indian, North Indian, Modern Indian, Maharashtrian                       0.000000
# South Indian, North Indian, Modern Indian, Maharashtrian, Juices, Ice Cream    0.000000
# Street Food                                                                    1.700000
# Tea, Coffee                                                                    0.000000
# Unknown                                                                        0.000000
# Name: aggregate_rating, Length: 160, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Bakery                                                                         1.0
# Bakery, Beverages                                                              1.0
# Bakery, Burger, Cafe, Coffee                                                   1.0
# Bakery, Burger, Cafe, Coffee, Indian, Pizza, Sandwich                          1.0
# Bakery, Cafe, Chinese, Coffee, Fast Food, Healthy Food, Indian, Pizza          1.0
#                                                                               ...
# South Indian, North Indian, Modern Indian, Maharashtrian                       1.0
# South Indian, North Indian, Modern Indian, Maharashtrian, Juices, Ice Cream    1.0
# Street Food                                                                    1.0
# Tea, Coffee                                                                    1.0
# Unknown                                                                        1.0
# Name: price_range, Length: 160, dtype: float64
#
# Competitive Analysis for Amritsar:
# Top Competitors:
#                                    name                         cuisines  \
# 15114                  La Roma Pizzeria               Fast Food, Italian
# 15147  Bhai Kulwant Singh Kulchian Wale                     North Indian
# 15156            Gurdas Ram Jalebi Wala                           Mithai
# 15115                   Kesar Da Dhabha                     North Indian
# 15137                      Kanha Sweets  Fast Food, Mithai, North Indian
#
#        price_range  aggregate_rating
# 15114          2.0               4.9
# 15147          1.0               4.8
# 15156          1.0               4.7
# 15115          2.0               4.6
# 15137          1.0               4.6
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Asian, Chinese, Cafe, Continental, Mughlai    3.8
# American, Fast Food, Burger, Chinese                    3.4
# American, Italian, Indian                               3.9
# American, Pizza                                         3.7
# Asian                                                   3.4
#                                                        ...
# Street Food, North Indian                               0.0
# Tea, Sandwich                                           0.0
# Tea, Street Food                                        4.0
# Thai, Chinese                                           3.7
# Unknown                                                 0.0
# Name: aggregate_rating, Length: 247, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Asian, Chinese, Cafe, Continental, Mughlai    3.0
# American, Fast Food, Burger, Chinese                    2.0
# American, Italian, Indian                               3.0
# American, Pizza                                         4.0
# Asian                                                   4.0
#                                                        ...
# Street Food, North Indian                               1.0
# Tea, Sandwich                                           1.0
# Tea, Street Food                                        1.0
# Thai, Chinese                                           3.0
# Unknown                                                 1.0
# Name: price_range, Length: 247, dtype: float64
#
# Competitive Analysis for Aurangabad:
# Top Competitors:
#                   name                                       cuisines  \
# 17466       Green Leaf                          Chinese, North Indian
# 17487  Barbeque Nation  North Indian, Seafood, Chinese, Mediterranean
# 17473  Bhoj Restaurant                                   North Indian
# 17492       Kef Lounge                    North Indian, Chinese, Thai
# 17471    Gayatri Mewad      North Indian, Biryani, Chinese, Beverages
#
#        price_range  aggregate_rating
# 17466          3.0               4.9
# 17487          3.0               4.8
# 17473          2.0               4.7
# 17492          2.0               4.6
# 17471          1.0               4.6
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Asian, North Indian         3.900000
# Bakery                      1.590476
# Bakery, Cafe                3.600000
# Bakery, Desserts            2.233333
# Bakery, Fast Food, Pizza    3.800000
#                               ...
# Street Food                 2.340000
# Street Food, Beverages      3.300000
# Street Food, Fast Food      1.333333
# Street Food, Kebab          2.900000
# Unknown                     1.600000
# Name: aggregate_rating, Length: 216, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Asian, North Indian         4.000000
# Bakery                      1.142857
# Bakery, Cafe                1.000000
# Bakery, Desserts            1.285714
# Bakery, Fast Food, Pizza    1.000000
#                               ...
# Street Food                 1.000000
# Street Food, Beverages      1.000000
# Street Food, Fast Food      1.000000
# Street Food, Kebab          2.000000
# Unknown                     1.000000
# Name: price_range, Length: 216, dtype: float64
#
# Competitive Analysis for Bangalore:
# Top Competitors:
#                                          name  \
# 19630                              Biergarten
# 19638  Brew and Barbeque - A Microbrewery Pub
# 19939                        Milano Ice Cream
# 19938               AB's - Absolute Barbecues
# 19937                          Mainland China
#
#                                                 cuisines  price_range  \
# 19630  Continental, North Indian, Chinese, European, ...          4.0
# 19638              Continental, North Indian, BBQ, Steak          3.0
# 19939                                Ice Cream, Desserts          1.0
# 19938         European, Mediterranean, North Indian, BBQ          3.0
# 19937              Chinese, Asian, Sushi, Japanese, Thai          3.0
#
#        aggregate_rating
# 19630               4.9
# 19638               4.9
# 19939               4.9
# 19938               4.9
# 19937               4.9
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Asian, Continental, North Indian, South Indian, Chinese    4.200000
# American, Asian, European, North Indian                              4.200000
# American, BBQ                                                        4.500000
# American, Burger, Italian, Steak                                     3.900000
# American, Chinese, Continental, North Indian                         4.500000
#                                                                        ...
# Tibetan                                                              0.000000
# Tibetan, Momos                                                       2.433333
# Turkish, Rolls                                                       3.900000
# Turkish, Rolls, Middle Eastern                                       2.600000
# Vietnamese                                                           4.400000
# Name: aggregate_rating, Length: 899, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Asian, Continental, North Indian, South Indian, Chinese    3.0
# American, Asian, European, North Indian                              3.0
# American, BBQ                                                        4.0
# American, Burger, Italian, Steak                                     3.0
# American, Chinese, Continental, North Indian                         3.0
#                                                                     ...
# Tibetan                                                              1.0
# Tibetan, Momos                                                       1.0
# Turkish, Rolls                                                       1.0
# Turkish, Rolls, Middle Eastern                                       1.0
# Vietnamese                                                           3.5
# Name: price_range, Length: 899, dtype: float64
#
# Competitive Analysis for Bhopal:
# Top Competitors:
#                                       name  \
# 24902         MoShik's Homemade Chocolates
# 24655           Kebabsville - Sayaji Hotel
# 24601         Manohar Dairy And Restaurant
# 24666                   Gujrat Cold Drinks
# 24633  The Public House CafÃ© n Restaurant
#
#                                                 cuisines  price_range  \
# 24902                                           Desserts          1.0
# 24655                                       North Indian          4.0
# 24601  Street Food, South Indian, Fast Food, Desserts...          2.0
# 24666                                  Beverages, Juices          1.0
# 24633                   North Indian, Italian, Beverages          3.0
#
#        aggregate_rating
# 24902               4.9
# 24655               4.9
# 24601               4.8
# 24666               4.7
# 24633               4.7
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Andhra                                     3.800000
# Awadhi, Mughlai                            4.200000
# BBQ                                        3.600000
# BBQ, Continental, Chinese, North Indian    3.500000
# Bakery                                     2.136667
#                                              ...
# Tea, Coffee, Fast Food, Beverages          0.000000
# Tea, Fast Food                             0.000000
# Tea, Fast Food, Coffee                     3.500000
# Tea, Street Food                           2.800000
# Tibetan                                    3.500000
# Name: aggregate_rating, Length: 329, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Andhra                                     3.0
# Awadhi, Mughlai                            4.0
# BBQ                                        2.0
# BBQ, Continental, Chinese, North Indian    3.0
# Bakery                                     1.4
#                                           ...
# Tea, Coffee, Fast Food, Beverages          1.0
# Tea, Fast Food                             1.0
# Tea, Fast Food, Coffee                     1.0
# Tea, Street Food                           1.0
# Tibetan                                    1.0
# Name: price_range, Length: 329, dtype: float64
#
# Competitive Analysis for Bhubaneshwar:
# Top Competitors:
#                              name  \
# 27257         Chili's Grill & Bar
# 27267             Barbeque Nation
# 27322  Mamma Mia - Mayfair Lagoon
# 27318    Mad Moose Artisan Gelato
# 27283                 Moody Blues
#
#                                                 cuisines  price_range  \
# 27257                                 Tex-Mex, Fast Food          2.0
# 27267  Mediterranean, Asian, Continental, North India...          3.0
# 27322                          Continental, Bakery, Cafe          3.0
# 27318                       Italian, Ice Cream, Desserts          1.0
# 27283  Chinese, Italian, Continental, Mexican, Arabia...          3.0
#
#        aggregate_rating
# 27257               4.9
# 27267               4.9
# 27322               4.7
# 27318               4.7
# 27283               4.7
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American                                             0.000000
# American, Bakery, Burger, Pizza                      4.200000
# Andhra, North Indian, Biryani, Chinese               4.200000
# Arabian, Chinese, Biryani                            3.950000
# Arabian, Chinese, Continental, Thai, North Indian    3.400000
#                                                        ...
# Tea, Fast Food                                       2.850000
# Tex-Mex, Fast Food                                   4.900000
# Thai, Chinese                                        4.200000
# Tibetan, Momos                                       3.883333
# Unknown                                              0.000000
# Name: aggregate_rating, Length: 310, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American                                             1.0
# American, Bakery, Burger, Pizza                      1.0
# Andhra, North Indian, Biryani, Chinese               2.0
# Arabian, Chinese, Biryani                            2.0
# Arabian, Chinese, Continental, Thai, North Indian    3.0
#                                                     ...
# Tea, Fast Food                                       1.0
# Tex-Mex, Fast Food                                   2.0
# Thai, Chinese                                        2.0
# Tibetan, Momos                                       1.0
# Unknown                                              2.0
# Name: price_range, Length: 310, dtype: float64
#
# Competitive Analysis for Chandigarh:
# Top Competitors:
#                     name                            cuisines  price_range  \
# 29863     The Great Bear  North Indian, Italian, Continental          3.0
# 29897  Milkshake and Co.                Beverages, Fast Food          1.0
# 29882            Nando's    Portuguese, Wraps, Burger, Salad          3.0
# 29887            Chili's                   Mexican, American          3.0
# 30117            Baithak    North Indian, Chinese, Fast Food          3.0
#
#        aggregate_rating
# 29863               4.9
# 29897               4.9
# 29882               4.9
# 29887               4.8
# 30117               4.8
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American                                              3.800000
# American, Asian, North Indian, Desserts, Beverages    3.800000
# American, Beverages, Desserts                         4.533333
# American, Cafe                                        4.600000
# American, Italian, Cafe                               4.100000
#                                                         ...
# South Indian, North Indian                            2.600000
# Street Food                                           3.655556
# Street Food, Fast Food                                3.500000
# Street Food, North Indian                             4.000000
# Tea, Street Food                                      3.500000
# Name: aggregate_rating, Length: 285, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American                                              2.0
# American, Asian, North Indian, Desserts, Beverages    3.0
# American, Beverages, Desserts                         2.0
# American, Cafe                                        3.0
# American, Italian, Cafe                               3.0
#                                                      ...
# South Indian, North Indian                            2.5
# Street Food                                           1.0
# Street Food, Fast Food                                1.0
# Street Food, North Indian                             1.0
# Tea, Street Food                                      1.0
# Name: price_range, Length: 285, dtype: float64
#
# Competitive Analysis for Chennai:
# Top Competitors:
#                             name  \
# 33476  AB's - Absolute Barbecues
# 33462             Coal Barbecues
# 33463             Coal Barbecues
# 33499                    Bhangra
# 33466             Coal Barbecues
#
#                                                cuisines  price_range  \
# 33476            BBQ, North Indian, European, Beverages          3.0
# 33462  North Indian, Mediterranean, Asian, Arabian, BBQ          3.0
# 33463  North Indian, Mediterranean, Asian, Arabian, BBQ          3.0
# 33499                                      North Indian          2.0
# 33466  North Indian, Mediterranean, Asian, Arabian, BBQ          3.0
#
#        aggregate_rating
# 33476               4.9
# 33462               4.9
# 33463               4.9
# 33499               4.9
# 33466               4.9
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Burger, Chinese, Desserts, Panini, Italian, Momos        4.200
# American, Continental                                              4.100
# American, Continental, European, Italian                           4.100
# American, Continental, Mexican, Fast Food                          4.000
# American, European, Italian, Mexican                               3.600
#                                                                    ...
# Tibetan, Chinese                                                   4.100
# Tibetan, Chinese, Momos                                            3.900
# Tibetan, Momos                                                     3.875
# Turkish, Continental, Italian, North Indian, Asian, Thai, Salad    4.400
# Wraps, Rolls                                                       0.000
# Name: aggregate_rating, Length: 679, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Burger, Chinese, Desserts, Panini, Italian, Momos        2.0
# American, Continental                                              3.0
# American, Continental, European, Italian                           2.0
# American, Continental, Mexican, Fast Food                          2.0
# American, European, Italian, Mexican                               1.0
#                                                                   ...
# Tibetan, Chinese                                                   1.0
# Tibetan, Chinese, Momos                                            1.0
# Tibetan, Momos                                                     1.0
# Turkish, Continental, Italian, North Indian, Asian, Thai, Salad    4.0
# Wraps, Rolls                                                       1.0
# Name: price_range, Length: 679, dtype: float64
#
# Competitive Analysis for Coimbatore:
# Top Competitors:
#                                 name  \
# 45091       AB's - Absolute Barbecue
# 45094                 Burger Ka Baap
# 45109             The Chocolate Room
# 45090          Abitha Biriyani Hotel
# 45096  Valarmathi Kongunaatu Samayal
#
#                                          cuisines  price_range  \
# 45091  European, Mediterranean, North Indian, BBQ          3.0
# 45094                           Fast Food, Burger          2.0
# 45109                              Cafe, Desserts          2.0
# 45090                       Biryani, South Indian          2.0
# 45096                       South Indian, Biryani          2.0
#
#        aggregate_rating
# 45091               4.9
# 45094               4.8
# 45109               4.8
# 45090               4.7
# 45096               4.7
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Fast Food                            2.7
# Andhra, Chinese, North Indian, South Indian    3.6
# Andhra, Hyderabadi, North Indian               0.0
# Arabian                                        3.1
# Arabian, Indian                                2.5
#                                               ...
# Tea, Coffee, Beverages                         0.0
# Tea, Fast Food                                 0.0
# Thai, Chinese                                  3.4
# Thai, Malaysian, Indonesian, Chinese, Asian    4.0
# Wraps, Sandwich, Beverages                     3.2
# Name: aggregate_rating, Length: 297, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Fast Food                            1.0
# Andhra, Chinese, North Indian, South Indian    2.0
# Andhra, Hyderabadi, North Indian               2.0
# Arabian                                        1.0
# Arabian, Indian                                2.0
#                                               ...
# Tea, Coffee, Beverages                         1.0
# Tea, Fast Food                                 2.0
# Thai, Chinese                                  4.0
# Thai, Malaysian, Indonesian, Chinese, Asian    3.0
# Wraps, Sandwich, Beverages                     1.0
# Name: price_range, Length: 297, dtype: float64
#
# Competitive Analysis for Cuttack:
# Top Competitors:
#                                name                            cuisines  \
# 47950                     Jugaad Jn            North Indian, Rajasthani
# 47946            Meals and Memories               North Indian, Chinese
# 47923  Ice - Indian Chicken Express                           Fast Food
# 47927                  The Cocktail  North Indian, Chinese, Continental
# 47951                Hotel Neeladri               Chinese, North Indian
#
#        price_range  aggregate_rating
# 47950          1.0               4.0
# 47946          2.0               3.9
# 47923          2.0               3.9
# 47927          2.0               3.9
# 47951          2.0               3.9
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Arabian, North Indian, Chinese    3.400000
# Bakery                            3.178261
# Bakery, Fast Food                 1.650000
# Bakery, North Indian              0.000000
# Bengali, North Indian, Chinese    3.800000
#                                     ...
# Street Food                       1.233333
# Street Food, Fast Food            0.000000
# Street Food, Mithai               3.500000
# Tea, Fast Food                    3.150000
# Tibetan, Burger                   3.750000
# Name: aggregate_rating, Length: 107, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Arabian, North Indian, Chinese    2.00000
# Bakery                            1.26087
# Bakery, Fast Food                 1.50000
# Bakery, North Indian              1.00000
# Bengali, North Indian, Chinese    2.00000
#                                    ...
# Street Food                       1.00000
# Street Food, Fast Food            1.00000
# Street Food, Mithai               1.00000
# Tea, Fast Food                    1.00000
# Tibetan, Burger                   2.00000
# Name: price_range, Length: 107, dtype: float64
#
# Competitive Analysis for Darjeeling:
# Top Competitors:
#                               name  \
# 49842             Glenary's Bakery
# 49838  Glenary's Restaurant  & Bar
# 49840                    Keventers
# 49839             Kunga Restaurant
# 49841                         Park
#
#                                                 cuisines  price_range  \
# 49842                                             Bakery          1.0
# 49838  Beverages, Cafe, Chinese, Continental, North I...          3.0
# 49840                     Beverages, Desserts, Ice Cream          2.0
# 49839                                 Tibetan, Beverages          1.0
# 49841  Tibetan, Thai, Indian, Chinese, Bakery, Beverages          3.0
#
#        aggregate_rating
# 49842               4.2
# 49838               4.1
# 49840               4.1
# 49839               4.1
# 49841               3.7
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Bakery                                                                          1.057143
# Bengali                                                                         0.000000
# Bengali, Fast Food                                                              3.300000
# Beverages, Cafe, Chinese, Continental, North Indian, Momos                      4.100000
# Beverages, Chinese, Continental, Fast Food                                      0.000000
# Beverages, Chinese, North Indian, South Indian                                  3.200000
# Beverages, Chinese, Sandwich, South Indian                                      2.900000
# Beverages, Desserts, Ice Cream                                                  4.100000
# Biryani                                                                         0.000000
# Biryani, Chinese, North Indian                                                  0.000000
# Cafe                                                                            3.300000
# Cafe, Bakery, Italian, Continental                                              0.000000
# Cafe, Desserts, Beverages, Sandwich                                             0.000000
# Chinese                                                                         0.000000
# Chinese, Continental, Fast Food, Nepalese, North Indian, Sandwich, Beverages    3.200000
# Chinese, Continental, North Indian                                              0.000000
# Chinese, Continental, North Indian, South Indian                                0.000000
# Chinese, Indian                                                                 0.000000
# Chinese, North Indian                                                           0.000000
# Chinese, Tibetan                                                                0.000000
# Coffee, Bakery, Tea, Beverages                                                  3.600000
# Continental                                                                     3.200000
# Fast Food                                                                       0.457143
# Fast Food, Pizza                                                                3.200000
# Fast Food, Tibetan                                                              0.000000
# Finger Food                                                                     3.300000
# Indian                                                                          0.000000
# Italian, Indian, Chinese, Bakery                                                3.200000
# Mishti                                                                          0.640000
# Mishti, Indian                                                                  1.033333
# Nepalese                                                                        1.066667
# Nepalese, Indian, Chinese, Bengali                                              0.000000
# North Indian                                                                    3.200000
# North Indian, Bengali, Chinese                                                  0.000000
# North Indian, Chinese                                                           0.000000
# North Indian, Chinese, Continental, Cafe                                        0.000000
# North Indian, Chinese, Tibetan                                                  0.000000
# North Indian, Continental, Chinese                                              3.400000
# North Indian, European, Asian, Mediterranean                                    0.000000
# Pizza, Fast Food                                                                0.000000
# Sandwich                                                                        3.000000
# South Indian, Chinese                                                           0.000000
# South Indian, North Indian, Chinese                                             3.400000
# South Indian, North Indian, Chinese, Beverages                                  3.200000
# Street Food                                                                     0.000000
# Tea                                                                             3.233333
# Tea, Italian                                                                    3.500000
# Tibetan                                                                         1.066667
# Tibetan, Beverages                                                              4.100000
# Tibetan, Chinese                                                                0.000000
# Tibetan, Chinese, Indian                                                        0.000000
# Tibetan, Fast Food                                                              0.000000
# Tibetan, Indian, Chinese                                                        0.000000
# Tibetan, North Indian, Chinese                                                  3.500000
# Tibetan, Thai, Indian, Chinese, Bakery, Beverages                               3.700000
# Unknown                                                                         0.328571
# Name: aggregate_rating, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Bakery                                                                          1.000000
# Bengali                                                                         1.500000
# Bengali, Fast Food                                                              2.000000
# Beverages, Cafe, Chinese, Continental, North Indian, Momos                      3.000000
# Beverages, Chinese, Continental, Fast Food                                      1.000000
# Beverages, Chinese, North Indian, South Indian                                  1.000000
# Beverages, Chinese, Sandwich, South Indian                                      1.000000
# Beverages, Desserts, Ice Cream                                                  2.000000
# Biryani                                                                         1.000000
# Biryani, Chinese, North Indian                                                  1.000000
# Cafe                                                                            3.000000
# Cafe, Bakery, Italian, Continental                                              2.000000
# Cafe, Desserts, Beverages, Sandwich                                             2.000000
# Chinese                                                                         1.250000
# Chinese, Continental, Fast Food, Nepalese, North Indian, Sandwich, Beverages    2.000000
# Chinese, Continental, North Indian                                              3.500000
# Chinese, Continental, North Indian, South Indian                                3.000000
# Chinese, Indian                                                                 1.500000
# Chinese, North Indian                                                           2.000000
# Chinese, Tibetan                                                                2.000000
# Coffee, Bakery, Tea, Beverages                                                  2.000000
# Continental                                                                     2.000000
# Fast Food                                                                       1.142857
# Fast Food, Pizza                                                                2.000000
# Fast Food, Tibetan                                                              1.000000
# Finger Food                                                                     3.000000
# Indian                                                                          1.000000
# Italian, Indian, Chinese, Bakery                                                2.000000
# Mishti                                                                          1.200000
# Mishti, Indian                                                                  1.000000
# Nepalese                                                                        1.333333
# Nepalese, Indian, Chinese, Bengali                                              1.000000
# North Indian                                                                    2.000000
# North Indian, Bengali, Chinese                                                  2.000000
# North Indian, Chinese                                                           2.666667
# North Indian, Chinese, Continental, Cafe                                        3.000000
# North Indian, Chinese, Tibetan                                                  2.000000
# North Indian, Continental, Chinese                                              3.000000
# North Indian, European, Asian, Mediterranean                                    3.000000
# Pizza, Fast Food                                                                2.000000
# Sandwich                                                                        1.000000
# South Indian, Chinese                                                           1.000000
# South Indian, North Indian, Chinese                                             2.000000
# South Indian, North Indian, Chinese, Beverages                                  2.000000
# Street Food                                                                     1.000000
# Tea                                                                             1.000000
# Tea, Italian                                                                    3.000000
# Tibetan                                                                         1.333333
# Tibetan, Beverages                                                              1.000000
# Tibetan, Chinese                                                                1.000000
# Tibetan, Chinese, Indian                                                        1.000000
# Tibetan, Fast Food                                                              1.000000
# Tibetan, Indian, Chinese                                                        1.000000
# Tibetan, North Indian, Chinese                                                  2.000000
# Tibetan, Thai, Indian, Chinese, Bakery, Beverages                               3.000000
# Unknown                                                                         1.476190
# Name: price_range, dtype: float64
#
# Competitive Analysis for Dehradun:
# Top Competitors:
#                                      name  \
# 51329                     Barbeque Nation
# 51315                    Kalsang AMA Cafe
# 51318                        Punjab Grill
# 51430  Vatika Restaurant - Hotel Madhuban
# 51341                           Mirabilia
#
#                                         cuisines  price_range  \
# 51329  North Indian, Mediterranean, BBQ, Chinese          4.0
# 51315                                       Cafe          3.0
# 51318                      Mughlai, North Indian          4.0
# 51430         North Indian, Chinese, Continental          4.0
# 51341    North Indian, South Indian, Continental          4.0
#
#        aggregate_rating
# 51329               4.9
# 51315               4.8
# 51318               4.7
# 51430               4.7
# 51341               4.6
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American                                                                   3.6
# American, Burger, Fast Food                                                4.0
# American, Cafe, Italian                                                    3.5
# American, Fast Food, Desserts, Cafe, Italian, Sandwich, Wraps, Burger      4.4
# Asian, North Indian, Street Food, Indian, Continental, Italian, Chinese    4.3
#                                                                           ...
# Tea, Cafe, Continental                                                     0.0
# Thai, Chinese, North Indian                                                4.5
# Tibetan, Chinese                                                           3.8
# Tibetan, Continental, Beverages                                            3.5
# Unknown                                                                    3.5
# Name: aggregate_rating, Length: 267, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American                                                                   2.0
# American, Burger, Fast Food                                                2.0
# American, Cafe, Italian                                                    3.0
# American, Fast Food, Desserts, Cafe, Italian, Sandwich, Wraps, Burger      2.0
# Asian, North Indian, Street Food, Indian, Continental, Italian, Chinese    4.0
# ...
# 73144    Masala Darbar  North Indian, Biryani, Chinese          2.0
# 73183         Ambrosia         North Indian, Beverages          1.0
# 73160              KFC               Burger, Fast Food          2.0
# 73152    Shake It Baby            Beverages, Fast Food          2.0
#
#        aggregate_rating
# 73179               4.8
# 73144               4.7
# 73183               4.6
# 73160               4.6
# 73152               4.6
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Asian                                                                       0.000000
# BBQ, Chinese, Sandwich, Beverages, North Indian, Burger, Desserts, Pizza    3.300000
# Bakery                                                                      2.110000
# Bakery, Chinese, Desserts                                                   3.500000
# Bakery, Desserts                                                            1.866667
#                                                                               ...
# Tea, Fast Food                                                              3.500000
# Tea, Fast Food, Beverages                                                   4.200000
# Tea, Street Food                                                            3.000000
# Thai, North Indian, Mughlai, Continental, Chinese                           3.900000
# Unknown                                                                     1.177778
# Name: aggregate_rating, Length: 196, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Asian                                                                       1.000000
# BBQ, Chinese, Sandwich, Beverages, North Indian, Burger, Desserts, Pizza    2.000000
# Bakery                                                                      1.150000
# Bakery, Chinese, Desserts                                                   2.000000
# Bakery, Desserts                                                            1.111111
#                                                                               ...
# Tea, Fast Food                                                              1.000000
# Tea, Fast Food, Beverages                                                   1.000000
# Tea, Street Food                                                            1.000000
# Thai, North Indian, Mughlai, Continental, Chinese                           4.000000
# Unknown                                                                     1.277778
# Name: price_range, Length: 196, dtype: float64
#
# Competitive Analysis for Mohali:
# Top Competitors:
#                                name                          cuisines  \
# 30115             Milkshake And Co.              Beverages, Fast Food
# 29910               Barbeque Nation             North Indian, Chinese
# 30131                Ghar Ka Khaana  Fast Food, North Indian, Chinese
# 30138  DND - Daily Nutritional Diet                      Healthy Food
# 30139                  Uncle Jack's     American, Beverages, Desserts
#
#        price_range  aggregate_rating
# 30115          1.0               4.9
# 29910          3.0               4.6
# 30131          1.0               4.6
# 30138          2.0               4.5
# 30139          2.0               4.5
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Beverages, Desserts         4.500000
# Asian                                 4.300000
# Bakery                                2.533333
# Bakery, Cafe                          4.200000
# Bakery, Cafe, Italian                 3.600000
#                                         ...
# Street Food, Fast Food                3.400000
# Street Food, North Indian             3.200000
# Street Food, South Indian, Chinese    3.500000
# Tea, Fast Food                        3.100000
# Wraps, Rolls                          2.900000
# Name: aggregate_rating, Length: 139, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Beverages, Desserts         2.0
# Asian                                 2.0
# Bakery                                1.0
# Bakery, Cafe                          2.0
# Bakery, Cafe, Italian                 2.0
#                                      ...
# Street Food, Fast Food                1.0
# Street Food, North Indian             1.0
# Street Food, South Indian, Chinese    1.0
# Tea, Fast Food                        1.0
# Wraps, Rolls                          1.0
# Name: price_range, Length: 139, dtype: float64
#
# Competitive Analysis for Nayagaon:
# Top Competitors:
#                                                     name  \
# 29968  The Green Emerald - Forest Hill Golf & Country...
# 30039                      Sharma Indian Food   Pure Veg
# 31269                                        Shama Dhaba
# 30070                                  Sharma Sweet Shop
# 30712                                     Mahadev Sweets
#
#                                  cuisines  price_range  aggregate_rating
# 29968  North Indian, Continental, Chinese          3.0               4.1
# 30039                        North Indian          1.0               3.7
# 31269                        North Indian          1.0               3.6
# 30070                 Mithai, Street Food          1.0               3.3
# 30712       North Indian, Chinese, Mithai          2.0               3.3
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Bakery, Desserts                      2.8
# Beverages                             0.0
# Beverages, Fast Food                  0.0
# Fast Food, Beverages                  0.0
# Mithai                                0.0
# Mithai, Street Food                   3.2
# North Indian                          3.5
# North Indian, Chinese                 3.3
# North Indian, Chinese, Mithai         3.3
# North Indian, Continental, Chinese    4.1
# Name: aggregate_rating, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Bakery, Desserts                      1.0
# Beverages                             1.0
# Beverages, Fast Food                  1.0
# Fast Food, Beverages                  1.0
# Mithai                                1.0
# Mithai, Street Food                   1.0
# North Indian                          1.0
# North Indian, Chinese                 1.5
# North Indian, Chinese, Mithai         2.0
# North Indian, Continental, Chinese    3.0
# Name: price_range, dtype: float64
#
# Competitive Analysis for New Delhi:
# Top Competitors:
#                                    name                      cuisines  \
# 53884                Plum By Bent Chair                         Asian
# 54079              Dragonfly Experience  Finger Food, European, Asian
# 58137                   Doodle's Garden     North Indian, Continental
# 55792                      Xero Degrees               Cafe, Fast Food
# 58134  ABB - Andrea's Bar And Brasserie      Italian, Asian, European
#
#        price_range  aggregate_rating
# 53884          1.0               4.9
# 54079          4.0               4.9
# 58137          3.0               4.9
# 55792          2.0               4.9
# 58134          4.0               4.9
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American                                      4.600000
# American, Asian, Continental, North Indian    4.600000
# American, British, Continental, Salad         4.500000
# American, Burger, Pizza                       4.500000
# American, Burger, Pizza, Continental          3.666667
#                                                 ...
# Thai, European, North Indian, Pizza, Salad    4.400000
# Thai, Salad                                   4.200000
# Tibetan, Chinese, Momos                       3.900000
# Turkish, Rolls, Kebab                         2.900000
# Wraps, Healthy Food, Sandwich, Salad          2.800000
# Name: aggregate_rating, Length: 695, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American                                      2.0
# American, Asian, Continental, North Indian    3.0
# American, British, Continental, Salad         3.0
# American, Burger, Pizza                       2.0
# American, Burger, Pizza, Continental          2.0
#                                              ...
# Thai, European, North Indian, Pizza, Salad    4.0
# Thai, Salad                                   4.0
# Tibetan, Chinese, Momos                       2.0
# Turkish, Rolls, Kebab                         2.0
# Wraps, Healthy Food, Sandwich, Salad          1.0
# Name: price_range, Length: 695, dtype: float64
#
# Competitive Analysis for Noida:
# Top Competitors:
#                                name                               cuisines  \
# 56042                   Burma Burma                         Asian, Burmese
# 58148                   Fourty Four                            Continental
# 58182  The Chinese Vs North Kitchen       North Indian, Chinese, Fast Food
# 58186               The Rolls World            Rolls, Fast Food, Beverages
# 58188                Makhani Siingh  North Indian, Mughlai, Biryani, Rolls
#
#        price_range  aggregate_rating
# 56042          3.0               4.8
# 58148          2.0               4.8
# 58182          2.0               4.7
# 58186          2.0               4.7
# 58188          2.0               4.7
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Continental, North Indian                                  3.500000
# American, Fast Food, Burger, Rolls, Chinese, Continental, Italian    3.900000
# American, Fast Food, Pizza, Burger                                   3.900000
# American, Italian                                                    4.200000
# American, Tex-Mex, Salad                                             4.200000
#                                                                        ...
# Street Food, North Indian, Chinese                                   3.900000
# Tea, Fast Food                                                       3.866667
# Tibetan, Chinese, Momos                                              3.600000
# Turkish, Rolls                                                       2.700000
# Wraps, Healthy Food, Sandwich, Salad                                 3.700000
# Name: aggregate_rating, Length: 165, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Continental, North Indian                                  1.0
# American, Fast Food, Burger, Rolls, Chinese, Continental, Italian    2.0
# American, Fast Food, Pizza, Burger                                   2.0
# American, Italian                                                    3.0
# American, Tex-Mex, Salad                                             3.0
#                                                                     ...
# Street Food, North Indian, Chinese                                   2.0
# Tea, Fast Food                                                       1.0
# Tibetan, Chinese, Momos                                              1.0
# Turkish, Rolls                                                       2.0
# Wraps, Healthy Food, Sandwich, Salad                                 1.0
# Name: price_range, Length: 165, dtype: float64
#
# Competitive Analysis for Panchkula:
# Top Competitors:
#                      name                                           cuisines  \
# 29847       Hops n Grains                North Indian, Middle Eastern, Pizza
# 29833  Falcon Cafe Lounge               Cafe, Italian, Chinese, North Indian
# 29885           Ram Dairy           Street Food, Fast Food, Mithai, Desserts
# 30174              SHANGZ                                              Asian
# 30156     The Last Course  Cafe, Italian, Fast Food, Beverages, Ice Cream...
#
#        price_range  aggregate_rating
# 29847          4.0               4.6
# 29833          3.0               4.5
# 29885          1.0               4.4
# 30174          2.0               4.4
# 30156          1.0               4.4
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# American, Cafe, Healthy Food, Sandwich, Beverages, Burger, Pizza    4.00
# Asian                                                               4.40
# Bakery                                                              3.85
# Bakery, Cafe                                                        4.30
# Bakery, Desserts                                                    3.40
#                                                                     ...
# South Indian, North Indian, Chinese                                 3.90
# Street Food                                                         2.52
# Street Food, Fast Food, Mithai, Desserts                            3.85
# Street Food, Mithai, North Indian, Chinese, Fast Food               3.40
# Street Food, North Indian                                           4.00
# Name: aggregate_rating, Length: 103, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# American, Cafe, Healthy Food, Sandwich, Beverages, Burger, Pizza    3.0
# Asian                                                               2.0
# Bakery                                                              1.5
# Bakery, Cafe                                                        2.0
# Bakery, Desserts                                                    1.0
#                                                                    ...
# South Indian, North Indian, Chinese                                 2.0
# Street Food                                                         1.0
# Street Food, Fast Food, Mithai, Desserts                            1.0
# Street Food, Mithai, North Indian, Chinese, Fast Food               2.0
# Street Food, North Indian                                           1.0
# Name: price_range, Length: 103, dtype: float64
#
# Competitive Analysis for Zirakpur:
# Top Competitors:
#                                name  \
# 30128                  Gourmet Nine
# 29878                        Hangry
# 30164                        Subway
# 33139  DND - Daily Nutritional Diet
# 30884                  Boston Fries
#
#                                                 cuisines  price_range  \
# 30128                 Andhra, Goan, North Indian, Kerala          3.0
# 29878  Cafe, Continental, Burger, Sandwich, Beverages...          2.0
# 30164                            Fast Food, Healthy Food          2.0
# 33139                                       Healthy Food          2.0
# 30884  Burger, American, Beverages, Fast Food, Cafe, ...          1.0
#
#        aggregate_rating
# 30128               4.6
# 29878               4.4
# 30164               4.4
# 33139               4.2
# 30884               4.2
#
# Strengths and Weaknesses:
# Average Ratings by Cuisine:
# cuisines
# Andhra, Goan, North Indian, Kerala                   4.600000
# Bakery                                               0.000000
# Bakery, Burger, Sandwich, Pizza                      3.600000
# Bakery, Cafe                                         3.900000
# Bakery, Fast Food                                    3.366667
#                                                        ...
# Street Food                                          3.500000
# Street Food, Fast Food                               3.800000
# Street Food, Fast Food, Desserts, Bakery             3.500000
# Street Food, Fast Food, Desserts, Bakery, Rolls      3.500000
# Street Food, Fast Food, Desserts, Chinese, Bakery    3.700000
# Name: aggregate_rating, Length: 82, dtype: float64
#
# Average Price Range by Cuisine:
# cuisines
# Andhra, Goan, North Indian, Kerala                   3.0
# Bakery                                               1.0
# Bakery, Burger, Sandwich, Pizza                      1.0
# Bakery, Cafe                                         2.0
# Bakery, Fast Food                                    1.0
#                                                     ...
# Street Food                                          1.0
# Street Food, Fast Food                               1.0
# Street Food, Fast Food, Desserts, Bakery             1.0
# Street Food, Fast Food, Desserts, Bakery, Rolls      1.0
# Street Food, Fast Food, Desserts, Chinese, Bakery    1.0
# Name: price_range, Length: 82, dtype: float64

# %% [markdown]
# In the above code:
#
# - We group the data by city or region to identify major competitors in each area.
# - For each city or region, we extract relevant information about competitors, including their names, cuisines, price ranges, and aggregate ratings.
# - We sort the competitors based on their aggregate ratings in descending order to identify the top competitors.
# - We then analyze the strengths and weaknesses of these competitors, which may involve further analysis of cuisines, pricing, and ratings. For example, we calculate the average ratings and price ranges for each cuisine to identify trends and patterns.

# %%
# Group the data by region (city)
grouped_data = df.groupby('city')

# Initialize empty dictionaries to store competitors' information
competitor_cuisines = {}
competitor_pricing = {}
competitor_ratings = {}
top_restaurants = {}

# Loop through each region to analyze competitors
for city, data in grouped_data:
    # Calculate the most common cuisines in the region
    cuisines = pd.Series(data['cuisines'].str.split(',').sum()).value_counts().head(5)
    competitor_cuisines[city] = cuisines

    # Calculate the average pricing in the region
    avg_price = data['average_cost_for_two'].mean()
    competitor_pricing[city] = avg_price

    # Calculate the average ratings in the region
    avg_rating = data['aggregate_rating'].mean()
    competitor_ratings[city] = avg_rating

    # Find the top 5 restaurants in the region
    top_restaurants[city] = data[['name', 'cuisines', 'average_cost_for_two', 'aggregate_rating']].head(5)

# Display the major competitors in each region along with the top 5 restaurants
for city in grouped_data.groups.keys():
    print(f"Region: {city}")
    print("Top 5 Popular Cuisines:", competitor_cuisines[city])
    print("Average Pricing:", competitor_pricing[city])
    print("Average Ratings:", competitor_ratings[city])
    print("Top 5 Restaurants:")
    print(top_restaurants[city])
    print()
# Out:
# Region: Agra
# Top 5 Popular Cuisines: North Indian    277
#  Chinese        142
#  Fast Food      118
# Mithai           99
#  Continental     83
# Name: count, dtype: int64
# Average Pricing: 520.6002400960384
# Average Ratings: 2.6612244897959187
# Top 5 Restaurants:
#                              name  \
# 0                     Bikanervala
# 1  Mama Chicken Mama Franky House
# 2                   Bhagat Halwai
# 3                   Bhagat Halwai
# 4     The Salt Cafe Kitchen & Bar
#
#                                             cuisines  average_cost_for_two  \
# 0  North Indian, South Indian, Mithai, Street Foo...                 700.0
# 1  North Indian, Mughlai, Rolls, Chinese, Fast Fo...                 600.0
# 2                                  Fast Food, Mithai                 300.0
# 3          Desserts, Bakery, Fast Food, South Indian                 300.0
# 4                 North Indian, Continental, Italian                1000.0
#
#    aggregate_rating
# 0               4.4
# 1               4.4
# 2               4.2
# 3               4.3
# 4               4.9
#
# Region: Ahmedabad
# Top 5 Popular Cuisines: North Indian    276
#  Fast Food      202
# Fast Food       135
#  Chinese        121
# Cafe            100
# Name: count, dtype: int64
# Average Pricing: 492.7506014434643
# Average Ratings: 3.20962309542903
# Top 5 Restaurants:
#                 name                          cuisines  average_cost_for_two  \
# 2622      Ph Se Food  North Indian, Chinese, Fast Food                 900.0
# 2623       Millhouse              Continental, Italian                1200.0
# 2624  The Red Bistro    Mexican, Italian, North Indian                1400.0
# 2625    Kadak Bhagat  North Indian, Chinese, Fast Food                1000.0
# 2626   Urban Khichdi         North Indian, Continental                 600.0
#
#       aggregate_rating
# 2622               4.5
# 2623               4.5
# 2624               4.6
# 2625               4.4
# 2626               4.7
#
# Region: Ajmer
# Top 5 Popular Cuisines: North Indian     126
#  Chinese          74
# Fast Food         71
#  Fast Food        70
#  North Indian     61
# Name: count, dtype: int64
# Average Pricing: 307.625
# Average Ratings: 2.5864999999999996
# Top 5 Restaurants:
#                          name  \
# 5936  Mango Masala Restaurant
# 5937                    Rasoi
# 5938               Bansi Wala
# 5939           Domino's Pizza
# 5940      Gangaur Pizza Point
#
#                                                cuisines  average_cost_for_two  \
# 5936  Continental, Beverages, South Indian, Fast Foo...                 600.0
# 5937  North Indian, South Indian, Continental, Itali...                 800.0
# 5938  Beverages, Fast Food, North Indian, Chinese, R...                 150.0
# 5939                                   Pizza, Fast Food                 400.0
# 5940                                   Fast Food, Pizza                 600.0
#
#       aggregate_rating
# 5936               4.8
# 5937               4.6
# 5938               4.2
# 5939               4.0
# 5940               4.4
#
# Region: Alappuzha
# Top 5 Popular Cuisines: South Indian     64
# Bakery           59
# Kerala           54
#  Kerala          39
#  North Indian    31
# Name: count, dtype: int64
# Average Pricing: 302.54901960784315
# Average Ratings: 0.3796078431372549
# Top 5 Restaurants:
#                           name  \
# 9213         Madras Veg Tables
# 9214  Halais Family Restaurant
# 9215             Arabian Shake
# 9216   Thaff Family Restaurant
# 9217                       KFC
#
#                                                cuisines  average_cost_for_two  \
# 9213                               South Indian, Kerala                 600.0
# 9214                               South Indian, Kerala                 450.0
# 9215                     Beverages, Desserts, Fast Food                 450.0
# 9216  Seafood, Chinese, Kerala, North Indian, South ...                 500.0
# 9217                                  Burger, Fast Food                 450.0
#
#       aggregate_rating
# 9213               3.5
# 9214               0.0
# 9215               4.0
# 9216               0.0
# 9217               0.0
#
# Region: Allahabad
# Top 5 Popular Cuisines: North Indian    227
#  Chinese        107
#  Fast Food       77
# Desserts         46
# Fast Food        44
# Name: count, dtype: int64
# Average Pricing: 353.54661791590496
# Average Ratings: 2.7252285191956127
# Top 5 Restaurants:
#               name                                          cuisines  \
# 11147       Eat On                                      North Indian
# 11148          KFC                                 Burger, Fast Food
# 11149   7th Heaven            Bakery, Italian, Continental, Desserts
# 11150  Sagar Ratna  South Indian, North Indian, Chinese, Continental
# 11151    Pizza Hut                         Pizza, Fast Food, Italian
#
#        average_cost_for_two  aggregate_rating
# 11147                 200.0               4.8
# 11148                 450.0               4.3
# 11149                 400.0               4.0
# 11150                 600.0               4.5
# 11151                 700.0               4.1
#
# Region: Amravati
# Top 5 Popular Cuisines: North Indian      100
#  Maharashtrian     60
# Fast Food          49
#  Chinese           47
#  Fast Food         47
# Name: count, dtype: int64
# Average Pricing: 213.57894736842104
# Average Ratings: 1.6907894736842106
# Top 5 Restaurants:
#                                  name  \
# 13262             Jazeerah Restaurant
# 13263  New Punjabi Dhaba & Restaurant
# 13264            New Eagle Restaurant
# 13265           Al Basheer Restaurant
# 13266                 Sahuji Ka Dhaba
#
#                                              cuisines  average_cost_for_two  \
# 13262  Malwani, Modern Indian, Roast Chicken, Seafood                 400.0
# 13263                     North Indian, Maharashtrian                 200.0
# 13264                                    North Indian                 200.0
# 13265                                    North Indian                 200.0
# 13266                                    North Indian                 200.0
#
#        aggregate_rating
# 13262               4.3
# 13263               4.5
# 13264               4.6
# 13265               4.4
# 13266               4.2
#
# Region: Amritsar
# Top 5 Popular Cuisines: North Indian     248
#  Chinese         121
#  Fast Food        99
#  Beverages        55
#  North Indian     52
# Name: count, dtype: int64
# Average Pricing: 469.63492063492066
# Average Ratings: 2.8788888888888895
# Top 5 Restaurants:
#                     name                                           cuisines  \
# 15114   La Roma Pizzeria                                 Fast Food, Italian
# 15115    Kesar Da Dhabha                                       North Indian
# 15116     R K Food Plaza  North Indian, Chinese, Fast Food, South Indian...
# 15117  Bharawan Da Dhaba  North Indian, Chinese, South Indian, Sandwich,...
# 15118            Hoppers  Cafe, Italian, Continental, Fast Food, Burger,...
#
#        average_cost_for_two  aggregate_rating
# 15114                 500.0               4.9
# 15115                 500.0               4.6
# 15116                 400.0               4.4
# 15117                 500.0               4.3
# 15118                 400.0               4.2
#
# Region: Aurangabad
# Top 5 Popular Cuisines: North Indian     199
#  Chinese         128
#  Fast Food        77
#  North Indian     64
# Fast Food         62
# Name: count, dtype: int64
# Average Pricing: 406.03945371775416
# Average Ratings: 2.7738998482549317
# Top 5 Restaurants:
#                    name                            cuisines  \
# 17464  SNT Tahari House              Maharashtrian, Biryani
# 17465    Amigos Kitchen  North Indian, Chinese, Continental
# 17466        Green Leaf               Chinese, North Indian
# 17467      Cone-N-Cakes                 Desserts, Fast Food
# 17468               KFC                   Burger, Fast Food
#
#        average_cost_for_two  aggregate_rating
# 17464                 400.0               4.4
# 17465                 500.0               4.4
# 17466                 750.0               4.9
# 17467                 300.0               4.4
# 17468                 450.0               4.4
#
# Region: Bangalore
# Top 5 Popular Cuisines:  North Indian    393
#  Chinese         355
# North Indian     329
#  Fast Food       264
#  Desserts        257
# Name: count, dtype: int64
# Average Pricing: 799.105473965287
# Average Ratings: 3.6981753449043167
# Top 5 Restaurants:
#                               name  \
# 19630                   Biergarten
# 19631  Byg Brewski Brewing Company
# 19632           The Bangalore Cafe
# 19633   Stories - The Brew Chapter
# 19634                  Big Pitcher
#
#                                                 cuisines  \
# 19630  Continental, North Indian, Chinese, European, ...
# 19631      Finger Food, Fast Food, North Indian, Italian
# 19632  Modern Indian, North Indian, Pizza, Continenta...
# 19633            Bar Food, Continental, Chinese, Italian
# 19634  American, Continental, North Indian, Mediterra...
#
#        average_cost_for_two  aggregate_rating
# 19630                2100.0               4.9
# 19631                1600.0               4.7
# 19632                 800.0               4.6
# 19633                2000.0               4.8
# 19634                1800.0               4.8
#
# Region: Bhopal
# Top 5 Popular Cuisines: North Indian    303
#  Fast Food      201
#  Chinese        179
#  Beverages      135
# Fast Food        86
# Name: count, dtype: int64
# Average Pricing: 408.97240618101546
# Average Ratings: 2.83719646799117
# Top 5 Restaurants:
#                                name  \
# 24601  Manohar Dairy And Restaurant
# 24602             Zam Zam Fast Food
# 24603         Sagar Gaire Fast Food
# 24604          Anni Bhai ki Biryani
# 24605                       Al-Beik
#
#                                                 cuisines  \
# 24601  Street Food, South Indian, Fast Food, Desserts...
# 24602          North Indian, Mughlai, Biryani, Fast Food
# 24603  North Indian, South Indian, Chinese, Fast Food...
# 24604                                            Biryani
# 24605                                          Fast Food
#
#        average_cost_for_two  aggregate_rating
# 24601                 400.0               4.8
# 24602                 500.0               4.3
# 24603                 300.0               4.6
# 24604                 250.0               4.5
# 24605                 300.0               4.3
#
# Region: Bhubaneshwar
# Top 5 Popular Cuisines: North Indian    205
#  Chinese        182
#  Biryani        145
# Fast Food        93
#  Fast Food       91
# Name: count, dtype: int64
# Average Pricing: 443.85078534031413
# Average Ratings: 3.070942408376963
# Top 5 Restaurants:
#                       name                                           cuisines  \
# 27257  Chili's Grill & Bar                                 Tex-Mex, Fast Food
# 27258  Upre Kitchen & Cafe  North Indian, Chinese, Continental, Italian, B...
# 27259         Biriyani Box                  Biryani, Hyderabadi, Rolls, Kebab
# 27260  Biryani Bhubaneswar                                            Biryani
# 27261           BOCCA Cafe                                 Cafe, Healthy Food
#
#        average_cost_for_two  aggregate_rating
# 27257                 700.0               4.9
# 27258                 600.0               4.2
# 27259                 350.0               4.0
# 27260                 300.0               4.0
# 27261                 450.0               4.6
#
# Region: Chandigarh
# Top 5 Popular Cuisines: North Indian     195
#  Fast Food       177
#  Chinese         127
#  North Indian     90
#  Beverages        63
# Name: count, dtype: int64
# Average Pricing: 663.9816232771823
# Average Ratings: 3.4722817764165383
# Top 5 Restaurants:
#                    name                                           cuisines  \
# 29812         Boathouse  European, Continental, North Indian, Finger Fo...
# 29814   Sector 7 Social  Continental, American, Asian, North Indian, Mo...
# 29815  Molecule Air Bar        Continental, North Indian, Chinese, Italian
# 29816       Burger King                       Burger, Fast Food, Beverages
# 29818  Pirates of Grill                                       North Indian
#
#        average_cost_for_two  aggregate_rating
# 29812                1600.0               4.7
# 29814                1400.0               4.6
# 29815                1000.0               4.2
# 29816                 500.0               4.0
# 29818                1200.0               4.5
#
# Region: Chennai
# Top 5 Popular Cuisines:  Chinese         388
#  North Indian    322
#  Fast Food       263
#  Desserts        227
# North Indian     226
# Name: count, dtype: int64
# Average Pricing: 731.9704433497537
# Average Ratings: 3.5977011494252875
# Top 5 Restaurants:
#                   name                                           cuisines  \
# 33460  The Black Pearl  North Indian, European, Mediterranean, Contine...
# 33461          Fromage                    Cafe, Italian, French, European
# 33462   Coal Barbecues   North Indian, Mediterranean, Asian, Arabian, BBQ
# 33463   Coal Barbecues   North Indian, Mediterranean, Asian, Arabian, BBQ
# 33464         The Bark                Cafe, Mexican, Italian, Continental
#
#        average_cost_for_two  aggregate_rating
# 33460                1500.0               4.8
# 33461                1000.0               4.5
# 33462                1400.0               4.9
# 33463                1400.0               4.9
# 33464                 800.0               4.4
#
# Region: Coimbatore
# Top 5 Popular Cuisines: South Indian     152
#  Fast Food       130
# Bakery           124
#  Chinese         113
#  South Indian    105
# Name: count, dtype: int64
# Average Pricing: 427.0717213114754
# Average Ratings: 2.802663934426229
# Top 5 Restaurants:
#                            name                                    cuisines  \
# 45090     Abitha Biriyani Hotel                       Biryani, South Indian
# 45091  AB's - Absolute Barbecue  European, Mediterranean, North Indian, BBQ
# 45092               Shahi Grill            Chettinad, North Indian, Chinese
# 45093                Cock Ra Co         North Indian, Chinese, South Indian
# 45094            Burger Ka Baap                           Fast Food, Burger
#
#        average_cost_for_two  aggregate_rating
# 45090                 700.0               4.7
# 45091                1400.0               4.9
# 45092                 350.0               4.2
# 45093                 550.0               4.2
# 45094                 500.0               4.8
#
# Region: Cuttack
# Top 5 Popular Cuisines: North Indian     97
#  Chinese         67
# Fast Food        45
#  North Indian    27
# Bakery           26
# Name: count, dtype: int64
# Average Pricing: 343.50877192982455
# Average Ratings: 2.820350877192982
# Top 5 Restaurants:
#                       name                                   cuisines  \
# 47914  Bawarchi Restaurant  North Indian, Chinese, Biryani, Fast Food
# 47915          New Mughlai      North Indian, Chinese, Biryani, Rolls
# 47916       Domino's Pizza                           Pizza, Fast Food
# 47917                Blast                      North Indian, Chinese
# 47918   DFC Dada's Biryani             Biryani, Chinese, North Indian
#
#        average_cost_for_two  aggregate_rating
# 47914                 500.0               3.7
# 47915                 500.0               3.5
# 47916                 400.0               3.6
# 47917                 500.0               3.8
# 47918                 400.0               3.8
#
# Region: Darjeeling
# Top 5 Popular Cuisines:  Chinese        26
# Unknown         21
# Chinese         14
# North Indian    12
#  Indian         12
# Name: count, dtype: int64
# Average Pricing: 416.25
# Average Ratings: 0.9612068965517241
# Top 5 Restaurants:
#                               name  \
# 49838  Glenary's Restaurant  & Bar
# 49839             Kunga Restaurant
# 49840                    Keventers
# 49841                         Park
# 49842             Glenary's Bakery
#
#                                                 cuisines  \
# 49838  Beverages, Cafe, Chinese, Continental, North I...
# 49839                                 Tibetan, Beverages
# 49840                     Beverages, Desserts, Ice Cream
# 49841  Tibetan, Thai, Indian, Chinese, Bakery, Beverages
# 49842                                             Bakery
#
#        average_cost_for_two  aggregate_rating
# 49838                1000.0               4.1
# 49839                 250.0               4.1
# 49840                 400.0               4.1
# 49841                 800.0               3.7
# 49842                 250.0               4.2
#
# Region: Dehradun
# Top 5 Popular Cuisines: North Indian    256
#  Chinese        178
#  Fast Food      112
# Fast Food        97
#  Continental     78
# Name: count, dtype: int64
# Average Pricing: 445.64575163398695
# Average Ratings: 2.803006535947712
# Top 5 Restaurants:
#                   name                          cuisines  \
# 51307      Doon Darbar             North Indian, Mughlai
# 51308   Gaylord Xpress                         Fast Food
# 51309     Uss Da Dhaba                      North Indian
# 51310   Domino's Pizza                  Pizza, Fast Food
# 51311  Mannu Fast Food  Fast Food, North Indian, Chinese
#
#        average_cost_for_two  aggregate_rating
# 51307                 500.0               4.3
# 51308                 200.0               3.8
# 51309                 350.0               4.2
# 51310                 400.0               3.9
# 51311                 250.0               4.6
#
# Region: Dharamshala
# Top 5 Popular Cuisines: North Indian     80
#  Chinese         71
#  North Indian    49
# Cafe             36
# Chinese          30
# Name: count, dtype: int64
# Average Pricing: 425.59183673469386
# Average Ratings: 1.636326530612245
# Top 5 Restaurants:
#                         name                               cuisines  \
# 59848             Illiterati                                   Cafe
# 59849          Tibet Kitchen  Chinese, North Indian, Tibetan, Momos
# 59850             Shiva Cafe                           North Indian
# 59851         Domino's Pizza                       Pizza, Fast Food
# 59852  Jimmy Italian Kitchen                                Italian
#
#        average_cost_for_two  aggregate_rating
# 59848                 800.0               4.3
# 59849                 600.0               4.0
# 59850                 500.0               3.9
# 59851                 400.0               3.6
# 59852                 500.0               3.8
#
# Region: Faridabad
# Top 5 Popular Cuisines: North Indian     30
#  Fast Food       17
#  Chinese         15
#  North Indian    14
#  Beverages        8
# Name: count, dtype: int64
# Average Pricing: 684.1772151898734
# Average Ratings: 3.2569620253164557
# Top 5 Restaurants:
#                            name  \
# 53928        Om Sweets & Snacks
# 53941                Pizza Live
# 54141    Oasis - Vivanta by Taj
# 54160  Paranda - Vivanta by Taj
# 54318                       BTW
#
#                                                 cuisines  \
# 53928    North Indian, South Indian, Street Food, Mithai
# 53941                                   Pizza, Fast Food
# 54141          Continental, North Indian, Asian, Italian
# 54160                              North Indian, Mughlai
# 54318  Mithai, North Indian, Chinese, South Indian, F...
#
#        average_cost_for_two  aggregate_rating
# 53928                 500.0               4.3
# 53941                 300.0               4.0
# 54141                2500.0               4.0
# 54160                2500.0               4.1
# 54318                 550.0               4.0
#
# Region: Gandhinagar
# Top 5 Popular Cuisines: North Indian    21
#  Fast Food      16
#  Chinese        14
#  Street Food    11
# Pizza            9
# Name: count, dtype: int64
# Average Pricing: 419.2708333333333
# Average Ratings: 2.853125
# Top 5 Restaurants:
#                                               name  \
# 2709                          Wooddy Jhone's Pizza
# 2713                                Domino's Pizza
# 2750  Earthen Oven - Fortune Inn Haveli Restaurant
# 2776        Orchid - Fortune Inn Haveli Restaurant
# 2782                Dum ka Zaika- Narayani Heights
#
#                                  cuisines  average_cost_for_two  \
# 2709                                Pizza                 500.0
# 2713                     Pizza, Fast Food                 400.0
# 2750                North Indian, Mughlai                1600.0
# 2776                North Indian, Mughlai                1400.0
# 2782  Mughlai, North Indian, South Indian                1300.0
#
#       aggregate_rating
# 2709               4.0
# 2713               3.3
# 2750               3.7
# 2776               3.7
# 2782               3.8
#
# Region: Gangtok
# Top 5 Popular Cuisines:  Chinese         42
# North Indian     20
# Unknown          16
#  North Indian    15
# Fast Food        14
# Name: count, dtype: int64
# Average Pricing: 512.9545454545455
# Average Ratings: 1.3893939393939392
# Top 5 Restaurants:
#                   name                            cuisines  \
# 61799   Osm Restaurant  North Indian, Continental, Chinese
# 61800           Nimtho                   Tibetan, Nepalese
# 61801  The Coffee Shop                       Italian, Cafe
# 61802   Taste of Tibet                    Tibetan, Chinese
# 61803        Chopstick                             Chinese
#
#        average_cost_for_two  aggregate_rating
# 61799                 800.0               3.5
# 61800                 650.0               3.5
# 61801                 800.0               3.6
# 61802                 500.0               3.4
# 61803                 800.0               3.5
#
# Region: Ghaziabad
# Top 5 Popular Cuisines: North Indian     27
#  Fast Food       24
#  North Indian    20
#  Chinese         19
#  Beverages       14
# Name: count, dtype: int64
# Average Pricing: 595.5555555555555
# Average Ratings: 3.4877777777777776
# Top 5 Restaurants:
#                                name                                  cuisines  \
# 53978           The Flying Dutchman          Bar Food, Finger Food, Fast Food
# 54073                       Berco's                      Chinese, Thai, Asian
# 54131  64/6 -  Country Inn & Suites  North Indian, Chinese, Thai, Continental
# 54269               Mystery of Food                     North Indian, Chinese
# 54280              Cinnamon Kitchen            North Indian, Chinese, Mughlai
#
#        average_cost_for_two  aggregate_rating
# 53978                1900.0               4.0
# 54073                1600.0               4.5
# 54131                3000.0               4.2
# 54269                1800.0               4.1
# 54280                1200.0               4.1
#
# Region: Goa
# Top 5 Popular Cuisines:  Chinese        249
#  Goan           244
# North Indian    207
#  Seafood        202
#  Continental    185
# Name: count, dtype: int64
# Average Pricing: 793.2869565217392
# Average Ratings: 3.0300869565217394
# Top 5 Restaurants:
#                             name  \
# 63394  Britto's Bar & Restaurant
# 63395                   Thalassa
# 63396      The Fisherman's Wharf
# 63397             Purple Martini
# 63398               Baba Au Rhum
#
#                                                 cuisines  \
# 63394  Chinese, Continental, Goan, North Indian, Seafood
# 63395                               Greek, Mediterranean
# 63396    Seafood, Goan, North Indian, Continental, Asian
# 63397  Continental, Seafood, Italian, Mediterranean, ...
# 63398                              Italian, French, Cafe
#
#        average_cost_for_two  aggregate_rating
# 63394                1400.0               4.4
# 63395                2000.0               4.4
# 63396                1100.0               4.8
# 63397                1500.0               4.9
# 63398                1000.0               4.7
#
# Region: Gorakhpur
# Top 5 Popular Cuisines: North Indian     134
#  Chinese          74
#  Fast Food        56
#  North Indian     54
# Bakery            51
# Name: count, dtype: int64
# Average Pricing: 295.0104821802935
# Average Ratings: 2.336897274633124
# Top 5 Restaurants:
#                            name                                  cuisines  \
# 66386            Domino's Pizza                          Pizza, Fast Food
# 66387      Chowdhry Sweet House  Mithai, North Indian, Chinese, Beverages
# 66388           Barbeque Nation                              North Indian
# 66389  Sher-E-Punjab Since 1965                     Mughlai, North Indian
# 66390             Pizza Station                                     Pizza
#
#        average_cost_for_two  aggregate_rating
# 66386                 400.0               4.1
# 66387                 500.0               4.3
# 66388                1600.0               4.9
# 66389                 500.0               4.3
# 66390                 300.0               4.3
#
# Region: Greater Noida
# Top 5 Popular Cuisines: North Indian     9
#  Fast Food       7
#  Beverages       5
#  Chinese         5
#  North Indian    3
# Name: count, dtype: int64
# Average Pricing: 473.8095238095238
# Average Ratings: 3.40952380952381
# Top 5 Restaurants:
#                  name                                           cuisines  \
# 54429     Burger King                       Burger, Fast Food, Beverages
# 54587    Creme Castle                Bakery, Mexican, Italian, Beverages
# 54745     Bikanervala  Mithai, Street Food, South Indian, North India...
# 54772      Haldiram's      North Indian, South Indian, Fast Food, Mithai
# 54962  New Soni Dhaba                                       North Indian
#
#        average_cost_for_two  aggregate_rating
# 54429                 500.0               4.1
# 54587                 700.0               4.2
# 54745                 600.0               3.9
# 54772                 600.0               3.9
# 54962                 150.0               3.6
#
# Region: Guntur
# Top 5 Popular Cuisines:  Chinese         79
#  North Indian    70
# Biryani          69
# South Indian     48
#  Beverages       34
# Name: count, dtype: int64
# Average Pricing: 336.74074074074076
# Average Ratings: 2.9703703703703703
# Top 5 Restaurants:
#                                name           cuisines  average_cost_for_two  \
# 68600                  Hotel Subani            Biryani                 600.0
# 68601  Chennai Thalapakatti Biryani            Biryani                 550.0
# 68602                           KFC  Burger, Fast Food                 450.0
# 68603            Babu Biryani Point            Biryani                 250.0
# 68604         Viceroy Biryani Point            Biryani                 350.0
#
#        aggregate_rating
# 68600               4.0
# 68601               3.8
# 68602               3.8
# 68603               3.7
# 68604               3.9
#
# Region: Gurgaon
# Top 5 Popular Cuisines: North Indian     165
#  North Indian    118
#  Chinese          97
#  Fast Food        87
#  Italian          76
# Name: count, dtype: int64
# Average Pricing: 982.2622950819672
# Average Ratings: 3.828524590163934
# Top 5 Restaurants:
#                             name  \
# 53889       The Drunken Botanist
# 53902  AB's - Absolute Barbecues
# 53915                 Feel Alive
# 53925                  Prankster
# 53934        Vapour Bar Exchange
#
#                                                 cuisines  \
# 53889        Continental, Italian, North Indian, Chinese
# 53902              European, Mediterranean, North Indian
# 53915  North Indian, Fast Food, Italian, Asian, Conti...
# 53925                            Bar Food, Modern Indian
# 53934       Continental, Italian, American, North Indian
#
#        average_cost_for_two  aggregate_rating
# 53889                2000.0               4.4
# 53902                1600.0               4.6
# 53915                1200.0               4.9
# 53925                1500.0               4.2
# 53934                1600.0               4.8
#
# Region: Guwahati
# Top 5 Popular Cuisines:  Chinese         185
# North Indian     155
#  North Indian     98
#  Fast Food        93
# Fast Food         67
# Name: count, dtype: int64
# Average Pricing: 505.5234159779614
# Average Ratings: 3.1068870523415972
# Top 5 Restaurants:
#                                     name  \
# 70518                                KFC
# 70519                     John's Kitchen
# 70520                    Barbeque Nation
# 70521                             Piazza
# 70522  Terra Mayaa Restaurant and Lounge
#
#                                                 cuisines  \
# 70518                                  Burger, Fast Food
# 70519                                   Chinese, Seafood
# 70520                        North Indian, Mediterranean
# 70521  Italian, Continental, Asian, Modern Indian, Pizza
# 70522                Continental, Italian, Indian, Asian
#
#        average_cost_for_two  aggregate_rating
# 70518                 450.0               4.2
# 70519                 350.0               4.6
# 70520                1600.0               4.9
# 70521                 800.0               4.4
# 70522                1400.0               4.1
#
# Region: Gwalior
# Top 5 Popular Cuisines: North Indian    209
#  Chinese         99
#  Fast Food       98
# Fast Food        59
# Bakery           48
# Name: count, dtype: int64
# Average Pricing: 329.05429071803854
# Average Ratings: 2.712434325744308
# Top 5 Restaurants:
#                            name  \
# 73140        Param Food Complex
# 73141            Domino's Pizza
# 73142  Ashoka Family Restaurant
# 73143               Burger King
# 73144             Masala Darbar
#
#                                                 cuisines  \
# 73140  North Indian, Bakery, South Indian, Seafood, B...
# 73141                                   Pizza, Fast Food
# 73142                                       North Indian
# 73143                       Burger, Fast Food, Beverages
# 73144                     North Indian, Biryani, Chinese
#
#        average_cost_for_two  aggregate_rating
# 73140                 600.0               4.5
# 73141                 400.0               4.0
# 73142                 350.0               4.2
# 73143                 500.0               4.3
# 73144                 400.0               4.7
#
# Region: Mohali
# Top 5 Popular Cuisines: North Indian     104
#  Fast Food        86
#  Chinese          60
#  North Indian     37
#  Beverages        33
# Name: count, dtype: int64
# Average Pricing: 441.8553459119497
# Average Ratings: 3.1097484276729563
# Top 5 Restaurants:
#                  name                                           cuisines  \
# 29813  Bhena Da Dhaba                                       North Indian
# 29817    Khalsa Dhaba      North Indian, Chinese, South Indian, Desserts
# 29819         Gopal's  Mithai, South Indian, North Indian, Fast Food,...
# 29820    Katani Dhaba                              North Indian, Chinese
# 29825    Amrit Sweets    Mithai, North Indian, South Indian, Street Food
#
#        average_cost_for_two  aggregate_rating
# 29813                 250.0               3.9
# 29817                 400.0               4.2
# 29819                 500.0               4.1
# 29820                 450.0               4.0
# 29825                 700.0               4.0
#
# Region: Nayagaon
# Top 5 Popular Cuisines: North Indian    7
#  Chinese        4
# Mithai          3
#  Street Food    2
# Beverages       2
# Name: count, dtype: int64
# Average Pricing: 336.6666666666667
# Average Ratings: 2.246666666666667
# Top 5 Restaurants:
#                                                     name  \
# 29968  The Green Emerald - Forest Hill Golf & Country...
# 30039                      Sharma Indian Food   Pure Veg
# 30070                                  Sharma Sweet Shop
# 30093                                       Bhatia Sweet
# 30096                            New Prince Juice Corner
#
#                                  cuisines  average_cost_for_two  \
# 29968  North Indian, Continental, Chinese                1800.0
# 30039                        North Indian                 100.0
# 30070                 Mithai, Street Food                 100.0
# 30093                 Mithai, Street Food                 100.0
# 30096                           Beverages                 100.0
#
#        aggregate_rating
# 29968               4.1
# 30039               3.7
# 30070               3.3
# 30093               3.1
# 30096               0.0
#
# Region: New Delhi
# Top 5 Popular Cuisines: North Indian     471
#  Chinese         304
#  Fast Food       304
#  North Indian    251
#  Italian         207
# Name: count, dtype: int64
# Average Pricing: 994.8708920187794
# Average Ratings: 3.727347417840375
# Top 5 Restaurants:
#                           name                                   cuisines  \
# 53884       Plum By Bent Chair                                      Asian
# 53885                 Pa Pa Ya             Asian, Chinese, Thai, Japanese
# 53886         Ministry Of Beer         Continental, Italian, Asian, Momos
# 53887                  Detroit                 Bar Food, Mexican, Italian
# 53888  The Darzi Bar & Kitchen  North Indian, Chinese, Continental, Pizza
#
#        average_cost_for_two  aggregate_rating
# 53884                   0.0               4.9
# 53885                2500.0               4.7
# 53886                1500.0               4.5
# 53887                1500.0               4.6
# 53888                1500.0               4.3
#
# Region: Noida
# Top 5 Popular Cuisines: North Indian     71
#  Fast Food       52
#  Chinese         51
#  North Indian    40
#  Mughlai         32
# Name: count, dtype: int64
# Average Pricing: 734.9808429118774
# Average Ratings: 3.620306513409962
# Top 5 Restaurants:
#                        name  \
# 53912          PizzaExpress
# 53937   Chili's Grill & Bar
# 54006  SodaBottleOpenerWala
# 54042      Pirates of Grill
# 54043               Berco's
#
#                                                 cuisines  \
# 53912                              Italian, Pizza, Salad
# 53937                 Mexican, American, Italian, Burger
# 54006  Parsi, North Indian, Beverages, Maharashtrian,...
# 54042          North Indian, Continental, Mughlai, Asian
# 54043                               Chinese, Thai, Asian
#
#        average_cost_for_two  aggregate_rating
# 53912                1900.0               4.2
# 53937                2000.0               4.7
# 54006                1700.0               4.3
# 54042                1800.0               4.2
# 54043                1600.0               4.3
#
# Region: Panchkula
# Top 5 Popular Cuisines: North Indian     47
#  Chinese         37
#  Fast Food       37
#  North Indian    32
# Fast Food        18
# Name: count, dtype: int64
# Average Pricing: 607.4404761904761
# Average Ratings: 3.1375
# Top 5 Restaurants:
#                      name                                       cuisines  \
# 29833  Falcon Cafe Lounge           Cafe, Italian, Chinese, North Indian
# 29845                 KFC                              Burger, Fast Food
# 29846       Anupam Sweets  Mithai, North Indian, South Indian, Fast Food
# 29847       Hops n Grains            North Indian, Middle Eastern, Pizza
# 29852      Domino's Pizza                               Pizza, Fast Food
#
#        average_cost_for_two  aggregate_rating
# 29833                1100.0               4.5
# 29845                 450.0               4.0
# 29846                 600.0               3.9
# 29847                2100.0               4.6
# 29852                 400.0               3.9
#
# Region: Zirakpur
# Top 5 Popular Cuisines: North Indian     54
#  Fast Food       36
#  Chinese         34
#  Desserts        17
#  North Indian    16
# Name: count, dtype: int64
# Average Pricing: 556.3333333333334
# Average Ratings: 2.8033333333333332
# Top 5 Restaurants:
#                                        name  \
# 29878                                Hangry
# 29923             Fuse Bar - Radisson Hotel
# 29932                           Bottle Room
# 29933  Illusion Bar - Velvet Clarks Exotica
# 29944                Feast - Radisson Hotel
#
#                                                 cuisines  \
# 29878  Cafe, Continental, Burger, Sandwich, Beverages...
# 29923  Finger Food, North Indian, Chinese, Thai, Euro...
# 29932                          North Indian, Continental
# 29933                                        Finger Food
# 29944              North Indian, European, Chinese, Thai
#
#        average_cost_for_two  aggregate_rating
# 29878                 600.0               4.4
# 29923                2500.0               3.4
# 29932                2200.0               4.0
# 29933                2200.0               2.9
# 29944                2000.0               3.9

# %% [markdown]
# ### **Finding Best Rated resturant in Each City**

# %%
# Finding Best Rated resturant in Each City
# Group the data by city
grouped_data = df.groupby('city')

# Initialize empty lists to store the city names, best restaurant names, and their ratings
cities = []
best_restaurant_names = []
best_restaurant_ratings = []

# Loop through each city group to find the best-rated restaurant
for city, data in grouped_data:
    best_rated_restaurant = data.loc[data['aggregate_rating'].idxmax()]
    cities.append(city)
    best_restaurant_names.append(best_rated_restaurant['name'])
    best_restaurant_ratings.append(best_rated_restaurant['aggregate_rating'])

# Plot the data
plt.figure(figsize=(12, 6))

# Plot the best restaurant ratings as bars
plt.barh(cities, best_restaurant_ratings, color='skyblue', label='Rating')

# Plot the best restaurant names as text annotations
for i, city in enumerate(cities):
    plt.text(best_restaurant_ratings[i], i, best_restaurant_names[i], ha='left', va='center', fontsize=10)

# Customize the plot
plt.title('Best Rated Restaurant in Each City')
plt.xlabel('Aggregate Rating')
plt.ylabel('City')
plt.gca().invert_yaxis()  # Invert y-axis to display the highest-rated restaurant at the top
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Top Rated Restaurants by Average Rating Level**

# %%
outlets = df["name"].value_counts()
outlets
# Out:
# name
# Domino's Pizza             131
# Cafe Coffee Day            112
# Keventers                   86
# KFC                         79
# Baskin Robbins              77
#                           ...
# Murli                        1
# Malabar Bay                  1
# BYLI - Bet You Love It!      1
# Silbatti                     1
# Hotel Mascot                 1
# Name: count, Length: 15550, dtype: int64

# %%
# Inspect unique values in the 'aggregate_rating' column
unique_values = df['aggregate_rating'].unique()
print(unique_values)
# Out:
# [4.4 4.2 4.3 4.9 4.  3.8 3.4 4.1 3.5 4.6 3.9 3.6 4.5 4.7 3.7 4.8 3.2 0.
#  3.3 2.8 3.1 2.6 3.  2.7 2.9 2.2 2.3 2.4 2.5 2.1 1.8 2.  1.9 nan]

# %%
atleast_5_outlets = outlets[outlets > 4] # I have set the criteria of number of outlets to greater than 4 to remove some outliers.

# %%
# Convert 'aggregate_rating' to numeric, coerce errors to NaN
df['aggregate_rating'] = pd.to_numeric(df['aggregate_rating'], errors='coerce')

# Filter rows where 'name' is in atleast_5_outlets.index
filtered_df = df[df["name"].isin(atleast_5_outlets.index)]

# Group by 'name' and calculate the mean of 'aggregate_rating'
mean_ratings = filtered_df.groupby("name")["aggregate_rating"].mean()

# Sort the mean ratings in descending order and select the top 10
top10_chains_r = mean_ratings.sort_values(ascending=False)[:10].sort_values(ascending=True)

print(top10_chains_r)
# Out:
# name
# Kandoi Bhogilal Mulchand      3.833333
# Iscon Ganthiya                3.900000
# Chhaswala                     3.914286
# McDonald's                    3.918182
# The Belgian Waffle Co         3.960000
# Bikanervala                   3.960000
# Shakti - The Sandwich Shop    3.966667
# New Freeze Land               3.985714
# Farki                         4.050000
# La Pino'z Pizza               4.087500
# Name: aggregate_rating, dtype: float64

# %%
height = pd.Series(top10_chains_r.values).map(lambda x : np.round(x, 2))
bars = top10_chains_r.index
y_pos = np.arange(len(bars))
bars = top10_chains_r.index


fig = plt.figure(figsize=[11,7], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible("#424242")
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

#colors = ["green","blue","magenta","cyan","gray","yellow","purple","violet","orange","red","maroon"]
#random.shuffle(colors)
colors = ['#dcecc9', '#aadacc', '#78c6d0', '#48b3d3', '#3e94c0', '#3474ac', '#2a5599', '#203686', '#18216b', '#11174b']
plt.barh(y_pos, height, color=colors)

plt.xlim(3)
plt.xticks(color="#424242")
plt.yticks(y_pos, bars, color="#424242")
plt.xlabel("Number of outlets in India")

for i, v in enumerate(height):
    ax.text(v + 0.01, i, str(v), color='#424242')
plt.title("Top 10 Restaurant chain in India by Average Rating")


plt.show()

# %% [markdown]
# **Observation:**
# The absence of fast food chains in the top-rated establishments underscores a notable trend: maintaining a superior service quality amid the prevalence of fast food outlets proves challenging. This observation suggests a correlation between service excellence and rating, emphasizing the impact of service standards on customer satisfaction. As such, this analysis highlights the significance of consistent service delivery in garnering favorable ratings, particularly in an environment saturated with fast food options

# %%
top_rated=df[df['aggregate_rating']>4.5]

# %%
figure=px.bar(top_rated,x='city',y='aggregate_rating')

figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="122d2987-e9c2-4d1a-a179-41505bda83e2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("122d2987-e9c2-4d1a-a179-41505bda83e2")) {                    Plotly.newPlot(                        "122d2987-e9c2-4d1a-a179-41505bda83e2",                        [{"alignmentgroup":"True","hovertemplate":"city=%{x}\u003cbr\u003eaggregate_rating=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Agra","Agra","Agra","Agra","Agra","Agra","Agra","Agra","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ahmedabad","Ajmer","Ajmer","Allahabad","Allahabad","Allahabad","Allahabad","Amravati","Amravati","Amritsar","Amritsar","Amritsar","Amritsar","Amritsar","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Aurangabad","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bangalore","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhopal","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Bhubaneshwar","Chandigarh","Chandigarh","Panchkula","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Chandigarh","Mohali","Mohali","Chandigarh","Chandigarh","Chandigarh","Zirakpur","Chandigarh","Chandigarh","Mohali","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Chennai","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Coimbatore","Dehradun","Dehradun","Dehradun","Dehradun","Dehradun","Dehra ...

# %%
df.columns
# Out:
# Index(['res_id', 'name', 'establishment', 'url', 'address', 'city', 'city_id',
#        'locality', 'latitude', 'longitude', 'zipcode', 'country_id',
#        'locality_verbose', 'cuisines', 'timings', 'average_cost_for_two',
#        'price_range', 'currency', 'highlights', 'aggregate_rating',
#        'rating_text', 'votes', 'photo_count', 'opentable_support', 'delivery',
#        'takeaway', 'total_cuisines', 'opening_time', 'closing_time'],
#       dtype='object')

# %%
data.groupby(['aggregate_rating','rating_text']).size().reset_index()
# Out:
#     aggregate_rating rating_text   0
# 0                0.0   Not rated  27
# 1                2.3        Poor   1
# 2                2.4        Poor   1
# 3                2.5     Average   1
# 4                2.7     Average  11
# 5                2.8     Average   5
# 6                2.8    PrÅ¯mÄr   1
# 7                2.9     Average   6
# 8                3.0     Average   3
# 9                3.1     Average   4
# 10               3.2     Average  12
# 11               3.3     Average  12
# 12               3.4     Average   7
# 13               3.5        Good  11
# 14               3.6        Good   6
# 15               3.7        Good   7
# 16               3.8        Good   6
# 17               3.9        Good  12
# 18               4.0   Very Good   5
# 19               4.1   Very Good   6
# 20               4.2   Very Good   3
# 21               4.4   Very Good   2
# 22               4.6   Excellent   1
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['aggregate_rating'].plot(kind='hist', bins=20, title='aggregate_rating')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning:
#
# Glyph 155 (\x9b) missing from current font.
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('rating_text').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_helpers.py in _repr_html_(self)
#     200       with mpl.rc_context(dict(_MPL_STYLE_OPTIONS)):
#     201         data = self._plot_func('df', *self._args, **self._kwargs)
# --> 202         exec(data.code, {'df': self._df})  # pylint: disable=exec-used
#     203         self._chart = _quickchart_lib.autoviz.MplChart.from_current_mpl_state()
#     204
#
# <string> in <module>
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in __call__(self, *args, **kwargs)
#     918         if kind in self._dataframe_kinds:
#     919             if isinstance(data, ABCDataFrame):
# --> 920                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     921             else:
#     922                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in generate(self)
#     446         self._compute_plot_data()
#     447         self._setup_subplots()
# --> 448         self._make_plot()
#     449         self._add_table()
#     450         self._make_legend()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/core.py in _make_plot(self)
#    1258         scatter = ax.scatter(
#    1259             data[x].values,
# -> 1260             data[y].values,
#    1261             c=c_values,
#    1262             label=label,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '0'
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='aggregate_rating', y='0', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_helpers.py in _repr_html_(self)
#     200       with mpl.rc_context(dict(_MPL_STYLE_OPTIONS)):
#     201         data = self._plot_func('df', *self._args, **self._kwargs)
# --> 202         exec(data.code, {'df': self._df})  # pylint: disable=exec-used
#     203         self._chart = _quickchart_lib.autoviz.MplChart.from_current_mpl_state()
#     204
#
# <string> in <module>
#
# <string> in _plot_series(series, series_name, series_index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3759             if self.columns.nlevels > 1:
#    3760                 return self._getitem_multilevel(key)
# -> 3761             indexer = self.columns.get_loc(key)
#    3762             if is_integer(indexer):
#    3763                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
# -> 3655             raise KeyError(key) from err
#    3656         except TypeError:
#    3657             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '0'
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['aggregate_rating']
#   ys = series['0']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_4.sort_values('aggregate_rating', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('rating_text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='rating_text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('aggregate_rating')
# _ = plt.ylabel('0')
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning:
#
# Glyph 155 (\x9b) missing from current font.
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['aggregate_rating']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'aggregate_rating'}, axis=1)
#               .sort_values('aggregate_rating', ascending=True))
#   xs = counted['aggregate_rating']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_5.sort_values('aggregate_rating', ascending=True)
# for i, (series_name, series) in enumerate(df_sorted.groupby('rating_text')):
#   _plot_series(series, series_name, i)
#   fig.legend(title='rating_text', bbox_to_anchor=(1, 1), loc='upper left')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('aggregate_rating')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_6['aggregate_rating'].plot(kind='line', figsize=(8, 4), title='aggregate_rating')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7[0].plot(kind='line', figsize=(8, 4), title=0)
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_lib.py:32: UserWarning:
#
# Glyph 155 (\x9b) missing from current font.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_8['rating_text'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_8, x='aggregate_rating', y='rating_text', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_quickchart_helpers.py in _repr_html_(self)
#     200       with mpl.rc_context(dict(_MPL_STYLE_OPTIONS)):
#     201         data = self._plot_func('df', *self._args, **self._kwargs)
# --> 202         exec(data.code, {'df': self._df})  # pylint: disable=exec-used
#     203         self._chart = _quickchart_lib.autoviz.MplChart.from_current_mpl_state()
#     204
#
# <string> in <module>
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, inner, split, width, dodge, gap, linewidth, linecolor, cut, gridsize, bw_method, bw_adjust, density_norm, common_norm, hue_norm, formatter, log_scale, native_scale, legend, scale, scale_hue, bw, inner_kws, ax, **kwargs)
#    1722 ):
#    1723
# -> 1724     p = _CategoricalPlotter(
#    1725         data=data,
#    1726         variables=dict(x=x, y=y, hue=hue),
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in __init__(self, data, variables, order, orient, require_numeric, color, legend)
#      64     ):
#      65
# ---> 66         super().__init__(data=data, variables=variables)
#      67
#      68         # This method takes care of some bookkeeping that is necessary because the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in __init__(self, data, variables)
#     632         # information for numeric axes would be information about log scales.
#     633         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634         self.assign_variables(data, variables)
#     635
#     636         # TODO Lots of tests assume that these are called to initialize the
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py in assign_variables(self, data, variables)
#     677             # to centralize / standardize data consumption logic.
#     678             self.input_format = "long"
# --> 679             plot_data = PlotData(data, variables)
#     680             frame = plot_data.frame
#     681             names = plot_data.names
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in __init__(self, data, variables)
#      56
#      57         data = handle_data_source(data)
# ---> 58         frame, names, ids = self._assign_variables(data, variables)
#      59
#      60         self.frame = frame
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_core/data.py in _assign_variables(self, data, variables)
#     230                 else:
#     231                     err += "An entry with this name does not appear in `data`."
# --> 232                 raise ValueError(err)
#     233
#     234             else:
#
# ValueError: Could not interpret value `0` for `x`. An entry with this name does not appear in `data`.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_9['rating_text'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_9, x='0', y='rating_text', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(_df_8['rating_text'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(_df_8, x='aggregate_rating', y='rating_text', inner='stick', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-142-87c8d4065651>:5: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/events.py:89: UserWarning:
#
# Glyph 155 (\x9b) missing from current font.
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/pylabtools.py:151: UserWarning:
#
# Glyph 155 (\x9b) missing from current font.

# %% [markdown]
# ### **Top 10 Restaurants In India by Number of Chains**

# %%
top10_chains = df["name"].value_counts()[:10].sort_values(ascending=True)

# %%
height = top10_chains.values
bars = top10_chains.index
y_pos = np.arange(len(bars))

fig = plt.figure(figsize=[11,7], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible("#424242")
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

#colors = ["green","blue","magenta","cyan","gray","yellow","purple","violet","orange","red","maroon"]
#random.shuffle(colors)
colors = ["#f9cdac","#f2a49f","#ec7c92","#e65586","#bc438b","#933291","#692398","#551c7b","#41155e","#2d0f41"]
plt.barh(y_pos, height, color=colors)

plt.xticks(color="#424242")

plt.yticks(y_pos, bars, color="#424242")
plt.xlabel("Number of outlets in India")

for i, v in enumerate(height):
    ax.text(v+3, i, str(v), color='#424242')
plt.title("Top 10 Restaurant chain in India by Number of Outlets")


plt.show()

# %% [markdown]
# **Observation:** According to the above visualization, Indian market is majorly dominaed by big fast food chains

# %% [markdown]
# ### Establishment Types
# Number of restaurants by establishment type

# %%
est_count = df.groupby("establishment").count()["res_id"].sort_values(ascending=False)[:5]

fig = plt.figure(figsize=[8,5], frameon=False)
ax = fig.gca()
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_color("#424242")
ax.spines["bottom"].set_color("#424242")

#colors = ["green","blue","magenta","cyan","gray","yellow","purple","violet","orange","red","maroon"]
#random.shuffle(colors)
colors = ["#2d0f41",'#933291',"#e65586","#f2a49f","#f9cdac"]
plt.bar(est_count.index, est_count.values, color=colors)

plt.xticks(range(0, 6), color="#424242")
plt.yticks(range(0, 25000, 5000), color="#424242")
plt.xlabel("Top 5 establishment types")

for i, v in enumerate(est_count):
    ax.text(i-0.2, v+500, str(v), color='#424242')
plt.title("Number of Restaurants by Establishment Type")


plt.show()

# %%
top_rated=df[df['aggregate_rating']>4.5]
fig = px.scatter_mapbox(top_rated, lat="latitude", lon="longitude", hover_name="city", hover_data=["aggregate_rating", "name"],
                        color_discrete_sequence=["fuchsia"], zoom=4, height=300)
fig.update_layout(mapbox_style="open-street-map")
fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})
fig.update_layout(title='Highly rated Resturants Location',
                  autosize=True,
                  hovermode='closest',
                  showlegend=False)
fig.update_layout(
    autosize=False,
    width=800,
    height=500,)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f5030ff5-09b0-4236-a651-be88bfb81a2b" class="plotly-graph-div" style="height:500px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f5030ff5-09b0-4236-a651-be88bfb81a2b")) {                    Plotly.newPlot(                        "f5030ff5-09b0-4236-a651-be88bfb81a2b",                        [{"customdata":[[4.9,"The Salt Cafe Kitchen & Bar"],[4.6,"Pinch Of Spice"],[4.6,"Pinch Of Spice"],[4.6,"Cafe Turquoise Cottage"],[4.7,"Tea'se Me - Rooftop Tea Boutique"],[4.7,"D'Delicia"],[4.8,"Sheroes Hangout"],[4.6,"Turko Mughal - Ramada Plaza"],[4.6,"The Red Bistro"],[4.7,"Urban Khichdi"],[4.7,"Soulmate - Make Moments Memorable"],[4.8,"Huber & Holly"],[4.6,"Mocha"],[4.7,"Swati Snacks"],[4.8,"Kadak Bhagat"],[4.6,"Agashiye - The House Of MG"],[4.6,"Nini's Kitchen"],[4.9,"Buttercupp"],[4.6,"Barbeque Nation"],[4.6,"Roastery Cultur - The Coffee Company"],[4.7,"Kovallam"],[4.9,"Yanki Sizzlers"],[4.6,"Lijjat Khaman"],[4.9,"Yanki Sizzlers"],[4.7,"China House - Hyatt Regency"],[4.7,"Dravida - The Fern"],[4.9,"TG\u00e2\u0080\u0099s - The Oriental Grill - Hyatt"],[4.6,"Tomato's"],[4.8,"Hoglatto"],[4.7,"Sante Spa Cuisine"],[4.7,"Lollo Rosso"],[4.6,"Lollo Rosso"],[4.6,"Pabrai's Fresh & Naturelle"],[4.6,"BUBBLEPOP!"],[4.6,"Harry's Kitchen"],[4.6,"Pure Beans & Creams"],[4.8,"Mango Masala Restaurant"],[4.6,"Rasoi"],[4.8,"Eat On"],[4.6,"EDEN by Connoisseur"],[4.7,"Barbeque Nation"],[4.7,"The Vintage Kitchen"],[4.6,"New Eagle Restaurant"],[4.9,"Hotel Abdullah"],[4.9,"La Roma Pizzeria"],[4.6,"Kesar Da Dhabha"],[4.6,"Kanha Sweets"],[4.8,"Bhai Kulwant Singh Kulchian Wale"],[4.7,"Gurdas Ram Jalebi Wala"],[4.9,"Green Leaf"],[4.6,"Gayatri Mewad"],[4.7,"Bhoj Restaurant"],[4.8,"Barbeque Nation"],[4.6,"Kef Lounge"],[4.9,"Biergarten"],[4.7,"Byg Brewski Brewing Company"],[4.6,"The Bangalore Cafe"],[4.8,"Stories - The Brew Chapter"],[4.8,"Big Pitcher"],[4.9,"Byg Brewski Brewing Company"],[4.6,"ShakesBierre"],[4.9,"Brew and Barbeque - A Microbrewery Pub"],[4.6,"Truffles"],[4.9,"Communiti"],[4.9,"TBC Sky Lounge"],[4.8,"The Globe Grub"],[4.6,"Toit"],[4.8,"Biergarten"],[4.6,"Hammered"],[4.7,"The Black Pearl"],[4.8,"The Black Pearl"],[4.8,"AB's - Absolute Barbecues"],[4.6,"Levitate Brewery and Kitchen"],[4.7,"Burma Burma"],[4.7,"The Big Barbeque"],[4.6,"The Hole in the Wall Cafe"],[4.7,"TBC- Sky Lounge"],[4.7,"The London Curry House - The Royale Senate Hotel"],[4.6,"Gilly's Restobar"],[4.8,"The Boozy Griffin"],[4.7,"ECHOES Koramangala"],[4.6,"Vanilla Sky"],[4.6,"Koramangala Social"],[4.7,"Hammered"],[4.6,"House Of Commons"],[4.6,"XOOX Brewmill"],[4.6,"Pasta Street"],[4.6,"The Pizza Bakery"],[4.6,"Rim Naam - The Oberoi"],[4.6,"Windmills Craftworks"],[4.6,"Saffron - Radisson Blu"],[4.9,"Taaza Thindi"],[4.9,"Brahmin's Coffee Bar"],[4.7,"Taaza Thindi"],[4.7,"Arogya Ahaara"],[4.6,"Namma SLN"],[4.9,"Asia Kitchen By Mainland China"],[4.9,"AB's - Absolute Barbecues"],[4.9,"Mainland China"],[4.9,"AB's - Absolute Barbecues"],[4.9,"Milano Ice Cream"],[4.8,"AB's - Absolute Barbecues"],[4.8,"The Globe Grub"],[4.8,"AB's - Absolute Barbecues"],[4.8,"Barbeque Nation"],[4.8,"Barbecue by Punjab Grill"],[4.8,"Belgian Waffle Factory"],[4.8,"Sant\u00c3\u00a9 Spa Cuisine"],[4.8,"O.G. Variar & Sons"],[4.8,"Belgian Waffle Factory"],[4.7,"Vapour Brewpub and Diner"],[4.7,"CTR"],[4.7,"Yauatcha"],[4.7,"AB's - Absolute Barbecues"],[4.7,"Barbeque Nation"],[4.7,"Chili's American Grill & Bar"],[4.7,"Barbeque Nation"],[4.7,"Chianti"],[4.7,"Chianti"],[4.7,"Brik Oven"],[4.7,"Punjab Grill"],[4.7,"Lot Like Crepes"],[4.7,"AB's - Absolute Barbecue"],[4.7,"Street Storyss"],[4.7,"Belgian Waffle Factory"],[4.7,"Corner House Ice Cream"],[4.7,"Karma Kaapi"],[4.7,"Belgian Waffle Factory"],[4.7,"Bengaluru Cafe"],[4.7,"Sriracha Robata & Contemporary P ...

# %% [markdown]
# ## Market Gap Analysis:
# - Identify any gaps in the market that the restaurant chain can capitalize on
# (e.g., underrepresented cuisines, price ranges).

# %% [markdown]
# Based on the insights from the regional analysis of various cities, here are some potential market gaps that a restaurant chain could capitalize on:
#
# 1. **Underrepresented Cuisines**:
#    - In regions like Amravati, where Maharashtrian cuisine is popular but not extensively represented in the top restaurants, there is an opportunity to introduce more Maharashtrian food joints.
#    - In cities like Gandhinagar and Nayagaon, there is a lack of diversity in cuisines beyond North Indian, Fast Food, and Chinese. Introducing new cuisines like Continental, Italian, or Mediterranean could fill this gap.
#
# 2. **Specialty Food Segments**:
#    - Regions such as Alappuzha show a preference for South Indian and Kerala cuisines. There might be an opportunity to introduce specialty dishes or authentic Kerala cuisine restaurants catering to local tastes.
#    - In cities like Agra, which have a significant presence of Mithai shops but lack representation of specific cuisines like Italian or Japanese, introducing dessert-themed cafes or fusion restaurants could be a unique selling proposition.
#
# 3. **Price Range Differentiation**:
#    - In regions like Amritsar and Bangalore, where the average pricing is relatively high, there might be an opportunity to introduce budget-friendly options without compromising on quality. This could attract a wider customer base looking for affordable dining options.
#
# 4. **Health-Conscious Options**:
#    - With the growing trend of health-conscious dining, there might be a market gap in regions like Bhopal and Chandigarh for restaurants offering organic, vegan, or gluten-free options. Introducing such options could cater to health-conscious consumers and differentiate the restaurant chain from competitors.
#
# 5. **Delivery and Takeaway Services**:
#    - In regions where there is a high demand for delivery and takeaway services, investing in efficient delivery logistics and packaging solutions could capitalize on this market gap. This could be particularly relevant in urban areas where people often prefer ordering food online or grabbing quick meals on the go.
#
# By identifying and addressing these market gaps, a restaurant chain can strategically expand its presence and attract a diverse customer base, ultimately driving business growth and success.
